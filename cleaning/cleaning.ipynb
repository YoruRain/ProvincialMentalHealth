# %% [markdown]
# ## 数据清洗部分

# %% [markdown]
# ### 目的：
# - 尽可能将粉丝打榜、打卡抽奖、转载营销性质的微博和账号从数据集中排除
# - 保留那些使用微博来生活日常、心情状态的用户
# - 保留之后可能用的上的用户与微博信息字段，具体如下：
#   - 用户：用户 ID、昵称、性别、总微博数、IP 所在地
#   - 微博：微博 ID、用户 ID、微博文本、发布时间、点赞数、评论数、转发数

# %% [markdown]
# ### 1. 微博有效性判断
# - 这部分的清洗对象是**整条微博**
# - 对于文本长度不超过1的微博，直接删除
# - 对于文本中含有广告、转载、营销相关关键词的微博，直接删除

# %%
import re

def is_valid(text: str) -> bool:
    """
    判断该微博是否为有效微博，依据为广告、转载、营销相关的关键词
    如果微博中出现了关键词，则认为是无效微博，直接删除

    Args:
        text (str): 一条微博的文本内容

    Returns:
        bool: 微博是否是否有效
    """

    if len(text.strip()) <= 1:
        return False
    
    # 广告、转载相关关键词
    ad_keywords = [
        '点开红包', '现金红包', '好礼', '网页链接', 
        '我在参与', '连续签到', '粉打卡', '年度歌曲', 
        '免费围观', '关注超话', "蚂蚁庄园：", "森林驿站", 
        "头条文章", "注册微博", "注册微博", "闲鱼发布",
        "闲鱼号", "头像挂件"
    ]

    # 微博中含有任意一个关键词，则认为无效
    if any(kw in text for kw in ad_keywords):
        # print(f"微博“{text}”为抽奖、广告、转载等微博，删除")
        return False
    
    return True

# %% [markdown]
# ### 2. 微博中低价值内容清洗
# - 这部分的清洗对象是**一条微博中的部分内容**，具体做法是将相应的内容替换为空字符
# - “低价值内容”指微博文本中的 URL、“分享自”、“分享图片/视频”和多余空格
# - 相较于第一次项目：
#   - 保留了“@用户”，猜测或许**能在一定程度上反映该用户的社交水平**
#   - 保留了话题标签“#xxx#”，猜测或许能为**情绪事件的总结归纳**带来帮助

# %%
def clean_text(text):
    # 去除URL
    text = re.sub(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', text)
    
    # 去除分享来源信息（直接将“分享自”及其后面的所有信息去除）
    text = re.sub(r'(?:[（(])?分享自(?!己).*$', '', text)

    # 去除“分享图片/视频”文本
    text = re.sub(r'分享(图片|视频)', '', text)
    
    # 去除多余空格
    text = re.sub(r'[\s]+', ' ', text)
    
    # 去除纯表情符号的内容
    if len(re.sub(r'[\s]', '', text)) <= 1:
        return ''
    
    return text.strip()

# %% [markdown]
# 读取文件。这里事先从数据库的 `user` 表中提取前100个用户及其微博，作为清洗的测试样例

# %%
import json

file_name = "test100.json"

with open(file_name, 'r', encoding='utf-8') as f:
    user_dict:dict = json.load(f)

# %% [markdown]
# 按上述策略执行清洗任务

# %%
users_to_remove = []

for user_id, user_info in user_dict.items():
    weibos = user_info["weibo"]
    for weibo in weibos:
        weibo["text"] = clean_text(weibo["text"])
    old = len(weibos)

    # 删除文本长度过短和抽奖打卡微博
    weibos = [weibo for weibo in weibos if is_valid(weibo["text"])]
    new = len(weibos)
    user_info["weibo"] = weibos
    rmv = old - new
    if new < 10:
        print(f"删除了用户{user_id}的{rmv}条无效微博，剩余微博数（{new}）过少，需要将该用户清洗出数据集")
        users_to_remove.append(user_id)
            
for user_id in users_to_remove:
    del user_dict[user_id]

print(f"删除了{len(users_to_remove)}个用户")
# Out:
# 删除了用户1001148342的12条无效微博，剩余微博数（0）过少，需要将该用户清洗出数据集
# 删除了用户1011491753的21条无效微博，剩余微博数（5）过少，需要将该用户清洗出数据集
# 删除了用户1058548740的50条无效微博，剩余微博数（0）过少，需要将该用户清洗出数据集
# 删除了用户1144313674的48条无效微博，剩余微博数（2）过少，需要将该用户清洗出数据集
# 删除了4个用户

# %%
save_file = "test100cleaned.json"

with open(save_file, 'w', encoding='utf-8') as f:
    json.dump(user_dict, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### 3. 使用大模型进行清洗
# - 上面的清洗策略仅依据一些关键词和正则表达式识别低价值微博，但无法彻底清除掉那些粉丝打榜、转载营销的用户
# - 接下来调用 DeepSeek 的 API，让大模型完成这部分用户的清洗工作

# %% [markdown]
# #### 微博文本采样
# - DeepSeek 的 API 对长文本的接受度较高。为了提高清洗效率，这里在一次 API 的调用中，将多个用户的微博文本一同输入给大模型
# - 为了节约时间和费用，下面先对各用户的微博进行采样
# - 采样操作中对微博文本进行的操作仅作识别用户性质所用，并不会将这部分处理的文本用于后续的情感分析中
# - 基本采样策略：
#   - 微博内容预处理，去除话题标签、@用户、“微博视频”、日期部分
#   - 舍弃长度小于10的微博；对于长度超过最大长度（此处设为50）的微博，保留前50字并在后加上 `...`
#   - 将处理后的微博按长度排序，均匀抽取5条不同长度的微博，作为该用户的样本微博，供大模型分析所用

# %%
import random
from typing import List, Dict
import re

def sample_user_weibos(weibos: List[Dict], 
                      max_samples: int = 10,
                      min_samples: int = 3,
                      max_text_length: int = 50) -> str:
    """
    对用户的微博内容进行采样，用于LLM分析用户类型
    
    Args:
        weibos: 用户的微博列表，每个微博是一个字典，包含text等字段
        max_samples: 最大采样数量
        min_samples: 最小采样数量
        max_text_length: 每条微博的最大长度
    
    Returns:
        str: 采样后的微博文本，用换行符连接
    """
    def preprocess_text(text: str) -> str:
        # 去除话题标签 (#xxx#)
        text = re.sub(r'#.*?#', '', text)
        # 去除@用户
        text = re.sub(r'@\w+', '', text)
        # 去除“微博视频”部分
        text = re.sub(r'\s.+微博视频', '', text)
        # 去除日期部分
        text = re.sub(r'(\d{2,4}年\d{1,2}(月\d{1,2}(日)?)?|\d{1,2}月\d{1,2}日)', '', text)

        return text

    
    filtered_weibos = []
    for weibo in weibos:
        text = preprocess_text(weibo["text"])

        # 过滤掉太短的内容
        if len(text) < 10:
            continue

        # 截断过长的文本
        if len(text) > max_text_length:
            text = text[:max_text_length] + '...'

        filtered_weibos.append(text)
    
    # 如果过滤后的微博数量太少，可能说明这是个低价值用户
    if len(filtered_weibos) < min_samples:
        return '\n'.join(filtered_weibos)
    
    # 按微博的字数进行排序
    filtered_weibos.sort(key=lambda x: len(x))

    samples = []
    
    # 微博均匀采样
    if filtered_weibos:
        step = len(filtered_weibos) // (min(max_samples, len(filtered_weibos)) - 1)
        if step > 0:
            samples.extend(filtered_weibos[::step][:max_samples])
        else:
            samples.extend(random.sample(filtered_weibos, 
                                      min(max_samples-1, len(filtered_weibos))))
    
    return '\n'.join(samples)

# %% [markdown]
# 将用户 ID 与采样后的微博文本组成一个元组，保存在一个字典中

# %%
sampled_weibo_dict = {}

for user_id, user_info in user_dict.items():
    sampled_weibo_dict[user_id] = sample_user_weibos(user_info["weibo"])

# %%
sampled_weibo_dict
# Out:
# {'1000129923': '怎么会有这么蠢的人）\n看完访谈之后和亲友怒骂三百条\n我居然有两个隐身访问和删除记录访问欸！！！ 来看啥的呢\n教室在顶楼 旁边就是天台 站在天台门口吹风真的好舒服 风好大好爽\n好想搞狒狒食柿 又想打本又想搞oc 明天下午就解放了 解放了我就爽打爽睡爽画\n怎么天天不是左边太阳穴长痘就是右边太阳穴长痘 怎么天天太阳穴长痘啊一边消了另一边又起的）\n终于把置顶写完了！！！ （感觉写了好多））） ——— 一般称呼是希珞！ 少歌狒狒邦邦二次三次日常都会...\n楼下那家面馆 面倒是还行料也多 但是盖码饭是真烂啊 吃完上楼都半个小时了还有点反胃 饭粒又硬菜又油还...\n因为早起懒得换衣服 于是在31度的今天穿着昨天28度穿的薄毛衣 后悔了 不该犯这一下懒的 看着周围人...\n不是 有些人在图书馆能不能别发出大声音的莫名其妙的声音 大家都安安静静的学习或者休息 你一个人又是敲...',
#  '1001430012': '给土豆做了个家养宠物狂犬病抗体检测，结果阴性，有图有真相。\n土豆日记： 早上六点半醒来的时候，精神状态是一种特别的清爽。难道与降低了海拔高度有关吗？ 昨晚开了一...\n土豆日记： 说说黄粿 我的好几个朋友都和我一样酷爱龙泉安仁古镇的黄粿。多少年了！ 这一次带回来的黄粿...\n土豆日记： 醒来前做了一个热情洋溢、汗流浃背、不肯醒来的梦。 在一个叫做资阳或紫阳的地方，我是一个助...\n土豆日记： （一） 买了两双斯凯奇一脚蹬春夏款走路鞋，鞋柜终于爆棚了。为了挪出空间，就应该扔掉两双。...\n土豆日记： （一） 姜堰大炉烧饼 《舌尖上的中国》第四季中介绍了泰州市姜堰区的非遗项目大炉烧饼，是震...\n土豆日记： 有的人脚臭，是脚气重，痛苦又烦人。当年我们的父辈不少都是这样的，我们在童年的时候经常看见...\n土豆日记： 土豆今天应该是快乐的，因为爷爷为了处理自我说服不了的歉疚感，带着它一整天。 今天的工作是...\n土豆日记： （一） 苏州是个名副其实拥有农村、渔村和山村的地方。 农村就是农民居住和生活的地方，农民...\n土豆日记： 碧空如洗，8:35，淌过滚滚车流，来到望亭稻香小镇。这是一个在春天铺天盖地开满油菜花，初...',
#  '1005071045': '开屏看到粉粉的王鹤棣啦\n午后阳光正好，微风不燥\n悲桑，殉了6只小🐭，此鰐果然很惡\n 我的评分： 不用心好好做节目，有dcx在都不会看了\n我在上为  X  连续送心7天，获得“星品热爱官”称号！快来一起pick你心动的星品吧～ 星品影响力\n 嘿！我在上邂逅了一个疯狂心动的星品—— ，快来看看，说不定你的心动之选也在这里哦！ 星品影响力新宣...',
#  '1005603481': '黄金越来越高不可攀了\n不只是产后，很长时间都睡眠严重不足，非常不足。\n首饰店关掉了，我老公在家，这大哥好几年大白天不在家了，明显不适应\n我老公上班时间改成9点了，然后现在家里卫生有家政帮忙，忽然之间，多出来大把时间。\n潮汕牛肉的员工都认识我了，说让员工提前把雪花准备好，我老公吃饭，只要哪家好吃又卫生，他能来吃好久\n我家老二在冰场，DuangDuangDuang的走，我说给他找个教练，他不让。但看他在场子里，那感觉...\n我今天就吃了一顿晚饭，现在肚子疼拉肚子。不过这顿晚饭我吃的凉的。但晚饭我是5点多点吃的，都过了好几个...\n上个周一直身体不舒服，我老公还不停的有事情让我去跑腿，家里乱成了一锅粥，要打扫要洗衣服，今天我还把被...\n涨得太快了 我们家店铺这几天就停业了，回收业务继续，回收业务范围扩大了，回收量也变大了。砍去了黄金首...',
#  '1006429701': '今麦 你的郎来了（。）\n朋友圈里全是结婚的照片，吓鼠银了！\n一摸防晒霜就长痘！！某国货不是敏感肌品牌吗\n感觉deepseek特别温润如玉。。。汉语的魅力\n看见有人说菅田将晖的鼻子像厕所里立了一架钢琴哈哈哈\n异人之下2让文淇演陈朵真的太灵了。。这张脸一出来就让人挪不开眼\n我每天不写很多东西呃，，就把gpt免费额度用完就够了【阴暗爬行】\n我热爱生活的方式就是感受它，一切伟大的渺小的众声喧哗的飘若尘埃的，让万事如风穿膛过\n去年十月我说：舍友给我过生日好幸福，有人也这样给你过生日吗？176：没有，我一般不过生日。我：明年我...\n早睡晚起，小论文写了，每星期都去图书馆借书看，按照自己的喜好上健身课、写小说，不缺钱花、想吃啥就买啥...',
#  '1007111115': '凡事磨你，皆为渡你。\n行动永远是打败焦虑的最好办法， 做好眼前该做的， 好运定会如期而至。\n一位成功交易者的成长成本是远超常人想象的。金钱，时间，精力……无论哪一方面都大到难以想象，普通人无法...\n美国贝莱德财团的最大股东是先锋领航集团，并且贝莱德与先锋领航是互持对方股份，二者的紧密关系可见一般。...\n玄学小提醒： 1、当事态不利于你的时候， 尽量闭嘴，静就是吉，不乱就是不错。 2、尤其是心，千万不能...\n芒格给普通人的投资启示: 聚焦三大资产： 1. 生钱资产：股票、房子。 2. 无形资产：技能、认知。...\n人这一生。最重要的就是形象好。最重要的就是打扮。最重要的就是美貌。 形象打扮美貌是基础。 美貌在。基...\n强者都有一个罕见的能力：不入局。 人的 时间、精力、能量，都是有限的，而且人跟人之间的交往其实存在能...\n一个人的贵气是养出来的，养出内在的松弛坚定，外在的从容贵气，自会活出风轻云淡的富足感。 身带贵气的人...\n选择一个好公司，历史低位下跌的时候不要怕，分仓买入。 买后继续下跌，不要悔，继续买。即使买完可买现金...',
#  '1010165301': '感受不一样的元宵味道！这才能传承！\n多年的长寿花，依然这样灿烂！ 西安·文艺路\n黑天鹅又在周五出现了！涨涨跌跌也正常，回调下健康！\n月在元阳老虎嘴梯田拍照！美好的记忆！！ 摄影 长沙·长沙长好医院\n海棠—苏轼 东风袅袅泛崇光，香雾空蒙月转廊。只恐夜深花睡去，故烧高烛照红妆。 长沙·长沙长好医院\n青春岁月已老，我们依然在爬山和烧烤！ 周六下午来到有森林公园之称的湖南师范大学！首先到师大的桃子湖转...\n满腹经纶6 俗语：人生哪有一帆风顺的？ 雅词：人到洛阳花似锦，偏我来时不逢春。 满腹经纶7 俗语：错...\n为了能看到日出，早上6.20出发，来到靳江河边，无奈天公不作美，云雾遮挡，只能 看到太阳露出的影子一...\n满腹经纶30 俗语： 祝你长命百岁。 雅词：从今把定春风笑，切做人间长寿仙。 满腹经纶31 俗语：祝...',
#  '1011074602': '一睹大唐盛世颜 西安\n公司团建 我负责吃果盘\n还是宜昌的烤苕皮好吃 有节节根\n饿了 煮牛肉面吃 好吃就是有点咸\n说好的减肥，结果今天吃的都是长胖的东西\n团团圆圆 好柿发生 柿柿如意 [招财进宝]\n正准备点外卖 就喊我交房租 交完房租顿时心情不好了\n人事不干人事啊 公司里面人事的作用就是给员工添堵的吗？？？？？\n？昨天还在看她们之前的综艺来着，今天一打开手机看见的第一个新闻就是这个，我还以为是假的，这么年轻.....\n真的要嫁给你 怀孕无法工作你会养我吗 伸手要钱你会甩脸子吗 你能担起家里的责任吗 你在你的家会一直向...',
#  '1011874467': '“他们要打多久就打多久，一直打到完全胜利！”\n原来旺自己，是有玄学的。 只要牢记这几条， 你的人生就会迎来巨大的改变。 第一条：少内耗 别人的评价...\n单身女孩婚前22条保命认知： 1. 别嫁比自己穷的男人。 2. 不要倒贴给男方，人家不会感激。 3....\n做人：对上恭敬、对下不傲，是为礼； 做事：大不糊涂、小不计较，是为智； 对利：能拿六分，只拿四分，是...\n【：】对待外人，要热情热心、耐心宽容；回到家庭，更应该多一分克制、少一点脾气。脾气发出来是本能，压下...\n杨绛先生说：“如果别人说你两句，你就受不了，被干扰得吃不好，睡不好，你该多脆弱啊。何必计较呢，在乌鸦...\n说句实在话，现在的孩子都不适合结婚！ 1.女生在家里都二十多了，从不干家务，养尊处优，还嫌这嫌那，简...\n社会潜规则悟透了，会少走很多弯路！ 1、有钱就可以大大方方小气，没钱只能小心翼翼地大方。 2、一个人...\n要想婚姻之路顺畅一些，女人要记住这四点： 1、首先不要让男人把你看透，不要因为他瞬间心疼一下你，或者...\n刘震云说： 精打细算的人，往往一生清贫； 会修修补补的人，用的都是旧东西； 样样精通的人，一辈子都赚...',
#  '1013933125': '第11年。真快啊 时间。\n👸🏻历险记🍔 动物博物馆get√\n亮灯啦˚*̥(∗*⁰͈꒨⁰͈)*̥~\n喂🦜日~ 今日最佳希尔鸡和 没有人的艺术馆\n👸🏻历险记🍔 下面是三姥姥来考公主给上的招待\nKitty控小姐の今日开心~ (考公主说我俩一人一个\n第一次看了一场舞剧 还挺精彩 "回望来路，生命里每一次初见，都如此美好"\n出门十二个小时干了N件事の今天(„ಡωಡ„) (其实是个顺利的~术后两个月复查\n👸🏻历险记🍔 🍭 ᵕ̈ʜᵅᵖᵖᵞʙⁱʳᵗᑋᵈᵃᵞ ❣ 心里有爱♥眼里有光♥ 考公主四岁记❤\n👸🏻历险记🍔 考公主班上有对双胞胎 她总说跟其中一个玩 我很好奇她怎么分出来的 毕竟我看着都长一样 ...',
#  '1015090037': '编织一个梦幻的故事。\n如何敲打，健康知识普及\n自己的付出晚辈不一定喜欢。\n豆沙包好吃，想得到老爸的夸奖\n豆沙包七十年代人的美食回味。\n看看我98岁老爸的早餐吃了什么\n目前的状况能出去参加点活动是一件很奢侈的事。\n每次给98岁半卧床老爸理发时都要累的我一身汗。\n我的手机拍摄的最好看的景色。我一直珍藏在手机里。\n为下次能痛快的给老爸理发，这次老爸理完发奖励老爸一个雪糕。',
#  '1015302932': '【“又贵又难吃”的蔬菜却被喜茶等品牌疯抢\n小狗认为摸头是世界上最幸福的事，所以它想将这份幸福带给同样流浪的小猫咪\n（受访），北京，。当事人向上游记者表示，平时大公鸡很凶，这次是因为被放进了箱子里猫咪才敢出来挑衅它。...\n【】医生表示，睡眠时长并不是越久越好，而应该更加重视睡眠的质量。重庆医科大学附属第一医院精神科主任医...\n【】（采访），山东烟台，狗狗在家跑来跑去没事干，主人拉着狗狗到大棚内铺膜：它干了我小时候干的活，干得...\n【】近日，湖北巴东，83岁的李奶奶捡到装有万元现金的挎包，便到附近店铺，请店主帮忙报警。见到民警、摸...\n，中国家电及消费电子博览会上，海尔leader三筒懒人洗衣机正式线下亮相，两个小筒分别用来洗内衣和袜...\n【】近日，贵州花江峡谷大桥全桥桥面贯通，预计年内通车，届时2小时车程变2分钟成为现实。大桥主桥跨径1...\n【高手在民间！】一把剪刀、一张红纸、再加上一双灵巧的手，60岁农村阿姨剪出非遗剪纸作品，生动还原哪吒...\n【转发！】捆菜结、快速逃生结、日字口袋结、十字固定结、汤水口袋结，5种实用绳结系法，简单易学，戳↓一...',
#  '1015581375': '好吃好喝，自由自在。\n小朋友活动剩下的边角料 自己做一餐 主打不浪费\n和同事吃个午饭，聊聊天。 鲍鱼野菜饭，春笋酿虾肉，沸腾鱼。 镇江·庭喜·茶食\n 家常便饭：红烧大土豆，番茄鸡蛋，洋葱蚕豆，菠菜，烤鸡，韭黄肉丝，苋菜，小白菜油面筋。水果：山楂白萝...\n正好路过附近，位置比较偏，听说爆炒面不错，外表破破烂烂，里面还可以。点了一份猪肝汤面🍜，他家默认就是...\n五六年没见的，外地归来的老同学，临时约2小时。人到中年，太多不由己，加油～ 镇江·如果咖啡(招商·北...\n这家新店位于北固山景区附近，长江路与解放路的交叉口，店内装修清新舒适。面条劲道配菜新鲜，口汤底口味整...\n黄记面馆，正东路，飞泉早茶对面巷子进去，新开的。 点的爆炒鹅肠干拌面🍜，食材新鲜，锅气足，面是拌好端...\n慢柴土鸡汤冒菜 汤头清爽，配菜丰富，肉质新鲜，香～ 吃了一身汗，爽～ 店不大，人很多～ 镇江·慢柴大...\n南北煎饼，靠近西津渡和博物馆，附近面馆多，煎饼就这一家，一位阿姨打理，生意不错，节假日还要排队。不过...',
#  '1022600720': '青岛·青岛海尔洲际酒店\n青岛·维多利亚湾-八期\n程响《可能》 可能 （）\n青岛·青岛国际啤酒节金沙滩会场\n[调皮][拥抱][胜利] [得意] …… Go on 🏃♂️\n奧帆中心 橘子海 《情書》 來了 青岛·奥帆海洋文化旅游区·奥林匹克帆船中心\n365天拍摄计划 我来咯~新人报道，首发帖在线求互评ing，快来与我互动吧~ 很高兴认识大家哟\nLauren Daigle《You Say》 You Say （） …… You say I am ...\n青島地鐵🚇暢達全城 …… 中午還在洲際員工餐 吃了頓“鴨子”[得意][呲牙][调皮] 這會兒回黃島了...',
#  '1024611264': '最近没有什么工作动力\n 最近看，存档 悬而不决 荒野植被\n大家都在吐槽花知晓新品，而我觉得蛋糕和草莓好可爱\n周大福新款的蛇也太好看了，恨自己不属蛇，不然咬咬牙买了\n摇篮曲直接单jsk快1500，这样一比花🦐899的jsk问题也没那么大了\n可能是年龄到了，小巷人家的后劲比永夜星河足，好羡慕主角生活 （婆媳和重男轻女除外）\n 点火樱桃by木三观 中间4星 后段3.5星 不知道为啥有种绿野千鹤的感觉 轻松到有点像过家家，两个...\n 南方海啸by卡比丘 3.5星 有点短，细水长流型的，不太轰轰烈烈也没有狗血，想看官宣也木有 喜欢番...\n看那年今日发现5年前的今天也是和暖暖过圣诞！那时候是闪耀暖暖，现在是无限暖暖 发一发最近穿搭（手机端...\n 正在看 《仁心俱乐部》感觉主演还行才看的，前面OK，到中间主角团未婚的每个人都要整点非官方cp的桃...',
#  '1025714307': '说很喜欢很喜欢太阳，但一出就是夏天的暴晒你又不喜欢了。\n我现在最大的感触就是无论是哪方面的破格或叫破局都需要时机，急是急不来的，还要看命里有没有什么时候有，...\n降温一天后今天就是太阳天，起床就开始晒，午饭都搬飘窗上晒着吃，晒得很满意，满以为可以好好睡个午觉，可...\n发现自己的眼神偏差大到一颗米和一个蛋那么大。回来路上又看到一枝杆上结的褐色果果，根本不是出去时看见那...\n对比色标感觉自己就是色盲，主体色系都叫不全叫不准，更别说互相融入参杂后发展出更宽的色谱系。这在织物面...\n都活了半生有余，依然能找到一生中不同时期的相似感觉。几岁时、30多岁时、现在，几乎一模一样的感受，那...\n来得晚本来想等到看夕阳，结果现在都高高在上光芒四射不敢直视。已从室外搬进室内，旁边的老外（年纪大的外...\n午休醒来31度，滚烫捕人一米外，如夏烤的春光显示了炽烈的一面。这几天外出晒春光之后，也有些疲乏困倦，...\n奶茶店，我旁边的两小美女边吃边说以后再不为别人的好评买单了，不过也算吃过了有发言权，以前也吃了不少这...\n“过去必须s去新生才会来（物质或精神层面）”我也经常浏览星座方面的文字，觉得比命理的文字更有安慰鼓励...',
#  '1032458983': '春暖花开，春天在向你招手\n南京的樱花美不美 南京·河西中央公园\n上午好，今日晴，18-34度，东南风，宜旅游。\n早上好，今日晴，1-13度，北风，宜旅游和户外运动。\n早上好，今日晴，5-18度，东风，宜户外运动和旅游。\n上午好，今日阴，7-23度，西南风，宜户外运动和旅游。\n早上好，今日晴有雨，11-24度，东风，宜户外运动和旅游。\n今天给父母亲、爷爷奶奶、老祖宗上坟，清明节祭扫、缅怀、追思🙏🙏🙏\n早上好，今日农历三月初三，天气阴转多云，2-15度，东南风，宜户外运动和旅游。埃菲儿铁塔落成。',
#  '1033961260': '也是走过了这个PEK\n 👈🏻怎么有人自恋成这样\n请各位吃一口480💰的海鲜饭🥘\n不知道🍁理解的什么意思 但她一定想多了🤔\n晓茶上班第一天又开始觉得公司真好 同事真好✌🏻\n及川彻！我命中注定的纸片人！！ 我要把你的谷子全吃掉\n4.1这个赛道也是被孩子闯进来了。。（剪完先笑了一个多小时\n🈚️期存｜款➕1 盘🎫又盘到了5️⃣🈷️[哪吒嘟嘴] 原💰的春逝好幸福\n加码个xyx拍立得🥲🥲🥲（bushi 鉴于我的体质不太好 ps：我加了别的 玩玩抽象\n你以为你xjgzs啊。。敢出哈姆雷特 真是什么🍚都想给zgyyj送 放过我们可怜的剧女好吗 （ps：...',
#  '1035490573': '积极是一个动词。怎么让自己开心？ 就是做事情，行动。\n我和我的~倔强，爸爸说你养不了花，但是我还是想养，花园里有老桩苗，我挑了小叶的，从小养起，陪伴长大\n早起小区散步时遇见一对年龄和我相仿的夫妻，女的跟在男的后面扶着他的腰，男的在前面步履蹒跚，像是脑梗后...\n2024.8.19 与孩子的沟通每个年龄段是不一样的，如果是一成不变的方式会出现叙情障碍，最后变得无...\n2025.2.18 大太阳☄️ 从过年到现在每天状态有些迷糊，觉得空捞捞，心里想的太多，未具体落到实...\n今天开气预报多云阴天，但在中午1点多出太阳了，温和不刺眼睛，舒服。 和今天看娃的心情有相似之处，“守...\n《走进红楼》 ，刚刚新青年被放在了醒目的位置上，毛泽东工作完毕，便拿起杂志细细研读，这一期刊登了李大...\n开始新的一周了，坚持做早餐~感谢队友指导尝试一下凉拌水煮花生芹菜，花生提前一天泡水，煮的时间长了 ，...\n第十二集《播火安源》 这座矿井里可不太平，这里有瓦斯很重的“阎王殿”，那边有不断滴水的“水帘洞”哪个...\n今天温度15℃，办公室未开空调，体感舒适，绿植长势良好！早餐胡萝卜芹菜杆蒸菜，洒了少许面粉，和妈妈蒸...',
#  '1039197400': '日常vlog 回到正常的生活常态\n日常vlog 今日菜单 泡菜肥牛豆腐锅 香煎鲳鳊鱼 蚕豆炒鸡蛋 瓠子炒肉丝\n日常vlog 今日菜单 🌱皮蛋豆腐 🌱青椒土豆片 🌱莴笋炒胡萝卜 🌱红烧牛排 🌱菜秧蛋汤\n日常vlog 今年冬天阳台的花草很争气 鸭掌木蹭蹭冒绿芽 长寿花也复花成功 早餐一碗徐州米线 吃的很...\n日常vlog 落枕几天 也几天没睡好觉 起床到社区医院推拿后好了很多 我开玩笑和医生说 “将来这里是...\n日常vlog 第一次买马蹄莲 细细长长 也不知道开出来美不美 今天又是一个月一次的陪老爸复查的日子 ...\n日常vlog 一早上到医院帮老妈办了出院 一切顺利 一年后再复诊 奢侈的在盒马买了大连的樱桃 清脆爽...\n日常vlog 今日菜单 🌱清蒸鲈鱼 🌱肥肠炒酸菜 🌱西红柿炒鸡蛋 🌱荠菜豆腐肉圆汤 昨天的脑部核磁结...\n日常vlog 老黑去上海扫墓 我则完全躺平 吃完早餐 趁着还没到周末 去莫愁湖看海棠花 现在是莫愁湖...\n日常vlog 到亳州了不是毫州🤓 花戏楼肯定要去 砖雕是一绝 干了一辈子会计 第一次见到如此奇怪的算...',
#  '1040345572': '火烧眉毛了先玩再说。\n等一个自然而然的阴天☁️\n《勇敢开口的人先享受美食》\n从2到6 我们的队伍越来越壮大了\n除了闲逛就是吃 要不就是买零食不出门看剧的日子\n第一天来膝盖上的两块淤青➕破皮是仙林给的见面礼\n临沂卷煎饼确实香啊 我一个从不爱吃煎饼这种东西的都爱上了\n小众爱好 喜欢和wy看各种人朋友圈然后评价 回想和他们的事情\n我希望 (电视剧《匆匆那年》插曲) 我希望能拥有个明亮的落地窗——\n从图书馆出来阳光很好不算很晒 突然就想躺在草坪上晒太阳 这片草坪还从来没来过',
#  '1041044002': 'KPL长生 妈咪开门我系鼠鼠呀\n现在才来update一下寒假的小姐姐\nKPL长生🌱 穿鹅睡衣背miku包，我叫人机鼠鼠请记住\n那就吃点好的嗷！ p1 教你如何在车厢内禁止饮食的时候掩耳盗铃\n别给我玩抽象了 一天天不知道在背什么抽象内容 谁还在复习期末考试呀哈哈 哈哈哈哈哈哈。\n有没有人可以解释一下拼豆两小时烫豆已经一个半小时了这件事情？？？为什么这么慢急死我了。。。小红书找了...\n年总纪录片给我看得眼睛尿尿了 最后的十多分钟采访总结了这一年多来的路也完美升华，历经千帆皆不是，轻舟...\n 晚上为了看看我们Esmall.wc队长舌战，连挑战赛都没来得及打，而他的四个队员在隔壁快乐梦境大乱...\n妈妈原来这个叫躺赢... 狙击手：“怎么走哪里都有这个典韦” 鹅子姐：“六百六十六” 百评边路：杀光...',
#  '1043086511': '放在劝分组可以回复500楼\n除夕快乐🥳好悬没在病房吃上年夜饭\n收官就再告别一次 想把这两只毛绒绒的萌物永远并排摆放在我的床头柜上\n来世我要托生为一只电影院里的老鼠 黑灯瞎火 神出鬼没 窝在某个角角看片 并捡拾新鲜的薯条和爆米花吃\n每天啊每天18点准时点开腾讯追随滤镜大王 即刻拥有一段非常纯粹的轻盈的快活的情绪价值补给time！第...\n我已经很克制了不想每天像台人机一样夸夸这个滤镜但实在是喜欢得要死你们懂吗原本只是来搞抽象的怎么越爱越...\n（嚼嚼嚼）你说（嚼嚼嚼）还没看滤镜的人在等什么呢？除了和蓝底渐次有血海深仇 我想不出任何不看这个滤镜...\n蓝底说会选择那些能给自己带来力量感，也能给观众带来力量感的角色，以此带来的“一点点微弱的光亮”是“作...\n看到那种像走啊走被路边的狗咬了一口的黑帖我顶多难受但从不破防 dear的作品dear的演技dear可...',
#  '1044396822': '回忆 爱丁堡街头闲逛\n 坐在水边聊聊天给技工生活充充电\n 昨天落地前空中看伦敦，貌似伦敦眼伦敦桥都有了\n 穿新衣戴新帽，新年到！新年到！祝福大家新年好！饺子汤圆吃起来\n 小伙伴儿们年前一聚，小伙伴儿问姐怎么没戴戒指💍啊，种草小伙伴儿的黄色小方糖\n 去4S店取车，发现这两天二十七八度气温催得满街的花都爆开了，一点儿都不含蓄了呢\n 记录 今儿去试“明晃晃”的同款，灰色穿上是真好看，想起大哥昨儿说太职业了，算了，留给上班族吧，最终...\n 威斯敏斯特教堂&威斯敏斯特修道院（讲解器说它叫西敏寺），实地看和听了他们生、死、婚配…都在这里，更...\n 最近被迫提前住进了局部改造还没收拾的家，化身清洁工和技工，包括但不限于把纸箱里的东西归位、各种洗洗...\n 今儿工长带着老婆来售后服务，哎呀人家老婆那个皮肤白白嫩嫩的呀，问了人家就随便抹点擦脸油，可见妈生好...',
#  '1044688085': '赵萝蕤译《荒原》初读\n晚上必须吃笋 广州·友谊剧院\n梵高博物馆梵高自画像 荷兰·阿姆斯特丹\n长公主睡醒了 广州·广州番禺长隆野生动物世界\n《海边：瓦日迪·穆瓦德剧作集》影像随着文字一一浮现\n时隔两年再读卡夫卡传记，我更喜欢卡内蒂不蔓不枝，施塔赫太过旁逸斜出了。\n香港艺术节阿姆斯特丹小交响乐团、荷兰ISH舞集与班查剧团《荒原》电子场刊重点和剧照。\n“我没有文学的兴趣，我是由文学所构成，我不是其他的什么。也不可能是其他的什么。”施塔赫《卡夫卡传·关...\n佛子，譬如虚空，虽能容受一切诸物，而离有无。菩萨摩诃萨亦复如是，虽普入一切世间，而离世间想；虽勤度一...',
#  '1046200023': '大年初二｜巳巳如意，生生不息🌅。\n有一种美叫青岛，记录家乡的一天📷 青岛一切都是最好的安排 生活如诗日落 青岛\n大年初三｜回娘家[招财进宝] [好事莲莲] 一切都是最好的安排 生活如诗餐桌上的仪式感 青岛\n乙巳蛇年二月的第一天 💌清早被徐老师的日本手信叫醒 赶场陪小朋友看了 然后赴一场无肉不欢的韩料 抽了...\n🧧正月初八｜天公作美 开工大吉[好事莲莲] 跟那从腊月开到正月的玫瑰一起等我的小王子 [招财进宝]感...\n[招财进宝]正月十五｜闹元宵[好事莲莲] 午餐一斤重的战斧牛排很好 紫色的郁金香很美 宛如油画的晚霞...\n晨起而作，暮落而息 顺应天时，安于四季 小小欲望，点滴满足 加之今日份失而复得的快乐 感恩🙏🏻🙏🏻🙏...\n农历二月初一🐍 烟雾缭绕的一天 热气腾腾的一天 超级高效的一天 挥别二月和正月，迎来即将到来的三月 ...\n🪞 致敬春天 穿上了冬天都不曾穿过的羽绒服 如果说秋裤是对冬日的敬意（虽然一直没有） 那么羽绒服就是...\n那一刻你心里有场海啸，可你静静站着，没有让任何人知道。 ☕️ 一切都是最好的安排 生活如诗餐桌上的仪...',
#  '1050102111': '过了 腊八 就是年～\n考试日 120分的虔诚 ～\n考试日 继续加油～ 一串神秘数字～\n新的一年 依然喜欢 爬山 看海 放空～\n今日早餐: 煎蛋，鲜肉玉米馄饨，耙耙柑早餐打卡\n今日早餐: 葱油面，水煮蛋 想放假的周五～早餐打卡\n今日早餐: 二米粥，牛奶鸡蛋饼，鸡腿，虾仁茭白早餐打卡\n今日早餐: 红枣杂粮粥 煎蛋 炒西兰花胡萝卜 麻薯 蓝莓早餐打卡\n今日早餐: 蒸饺🥟，紫菜荷包蛋🍳，卡尔顿小蛋糕🍞，蓝莓🫐草莓🍓早餐打卡\n今日早餐: 杂粮饭，西红柿炒鸡蛋，炒菠菜，煎午餐肉 （不像早餐，午餐即视感 ）早餐打卡',
#  '1052264532': '迷上种菜了 咋都不长个\n来例假不能游泳的日子靠买新装备度日\n又爱上摄影了 胶片真香啊都不用修 拍了个老铁\n跟我老铁一天天的聊天记录拿出来都是段子 不是笑死就是笑死\n这个烟云十六声当作单机玩玩还行 怎么感觉像缝合怪 一变成网游就不行了不会了\n二月第八游1000m打腿300m 乐高好玩就是费手，指纹都给按没了，指纹锁都半天开不进去\n给deepseek发饮食记录帮助我减肥！ 感谢你提供晚餐和运动记录！以下是针对你晚餐和运动的详细分析...\n今天的泳池也太好了吧 一群消防员在训练全是八块腹肌肌肉男 游在一群消防员中间也太好了 吧 好像进了盘...\n关于摄影的感悟 时隔几年又重新爱上摄影，但是这次对摄影有了新的理解。以前想着怎么把人拍“美”，而现在...\n100块钱淘的垃圾新玩具 想按快门的手已经忍不住颤抖 无数画面在我脑海里闪现 再熬两天我就要拍出惊世...',
#  '1055933083': '这家子三天两头买热搜\n她还那么小，心态却已老了\n深秋紫竹苑—打卡北京紫竹院\n【北京千灯夜，春节必打卡】\n京秋樱桃沟—游国家植物园樱桃沟记录\n北京中考大概要出成绩了。貌似是阅卷老师们在拍纪念照\n整理手机内存，旧照新作，2020年仲夏打卡北京七孔桥花海\n我同学和她妹妹相差11个月，同个妈生的，一个年头一个年尾。神奇吗？\n回老家第一晚，睡到半夜就地震了 ，然后失眠到天亮。整个一天就是补觉，逛商场，走亲戚。\n就仿佛当年看红楼梦，王熙凤轰轰烈烈了一生，最后下线时一卷烂席草草收场。令人唏嘘的结局！',
#  '1056870811': '活着的花，有一万种开法。 生活碎片\n岛上，白鹦鹉随处可见，游客吃饭时，它们就站在阳台上，或者在附近飞来飞去，耐心等待时机。\n在岛上，我们拥有一辆电动代步车，一车四人，驾驶者坐在右侧，左侧同行。整个小岛的路高低起伏，路边绿植郁...\n鱼和熊掌不可兼得，永远如此。那么就做自己最喜欢的那件事，而不做那个贪心的人，这样你就快乐了。 PO推...\n微博上2022年也是发的南天竹花果，今年今日又插了南天竹。人的行为，对某事的喜欢，对某物的寻找，也都...\n罗英子去机场接刘铭时，还是抱着最后一丝希望的，刘铭的一番话，彻底的让她清醒了。她受到的伤害其实是很深...\n钟樱花是开得最早的樱花，的确是吊钟形的花朵，颜色深粉，所以也叫绯樱。大宁公园的人，不能叫多，应该是密...\n有人说： 世间最好的养生，莫过于止怨、少思、善忘。 经过了这么多的事情之后，越加赞同这个说法，止怨才...\n那天我们两个走到一条新的马路，路边的围墙反射出白色的光，如霜铺地，我对他说：这条路像极了小时候我们去...\n为道日损。损之又损，以至于无为。无为而无不为。以道认识世界，一个人就不会陷入固执，因为他看到了事物发...',
#  '1057623342': "主题：今日事今日毕。\n我居然要看《2025年世界肥胖报告》了！\n给小伙纸做了份意面🍝，再来点午餐音乐🎵。然而还没放两首就已经吃完了……\n“我希望我的女儿能够意识到这些权利从何而来，并明白权利并非永恒不变。这当然不仅仅是一部献给我女儿的电...\n“由于自然环境的严苛，人民必须学习以更包容的态度相处，以合作来应对环境的挑战。同样地，教育重自我成长...\n今天中午看了《一诺对话严飞&刘擎》，伴随吃饭、洗碗，也做了些小笔记，本来想着整理出所感所想还有金句，...\n📗The Master and His Emissary 《大师及他的使者》 由精神病学家Iain ...\n下午参加了社区的公益韵律操活动，有两位家长带了自己的孩子，令我惊讶的是，小朋友竟然没有加入我们，一直...\n下午要去汉口给学生上社团课，到的比较早，在附近找了一家☕店，本来只是想找个落脚点，没想到从进门的兔兔...\n𝗔𝗰𝘁𝗶𝘃𝗲 𝗔𝗽𝗿𝗶𝗹🔛4.1 承诺从今天开始，本月将更加活跃。𝘓𝘦𝘵'𝘴 𝘧𝘪𝘯𝘥 𝘸𝘢𝘺𝘴 𝘵...",
#  '1060028933': '双月湾非常适合吃海鲜、看海和放风筝的地方！以下是我为你准备的详细攻略： 吃海鲜 双月湾的海鲜非常新鲜...\n香港尖沙咀天星码头是一个集交通枢纽、旅游观光和文化活动于一体的综合性地点 一、交通枢纽功能 尖沙咀天...\n大理古城是一座充满历史和文化底蕴的城市，这里有着独特的白族建筑风格和丰富的文化遗产，是云南省的著名旅...\n双廊古镇唐宋时南诏大理国的重塞，历史悠久，文化底蕴深厚。一份详细的双廊古镇游玩攻略： 云南省大理白族...\n香格里拉金沙江畔那独特而迷人的风景！香格里拉确实是一个充满魅力的地方，而金沙江流域更是以其壮观的自然...\n🌊 北海银滩，周末遛娃好去处，小朋友们的海边天堂！ 如果你不出海也不上岛，那么北海银滩绝对能满足你对...\n🌈探索丽江古城，一张图就足够！还有玉龙雪山游玩秘籍哦！ 🚗交通小贴士🚗 从机场到古城超方便！机场大巴...\n深圳宝安国际机场作为粤港澳大湾区的重要航空枢纽 深圳宝安国际机场简介 深圳宝安国际机场（Shenzh...\n重庆的空中门户，重庆江北国际机场，重要地位不言而喻 重庆江北国际机场简介 重庆江北国际机场（Chon...\n深圳莲花山是城市与自然和谐共存的典范。它位于市中心北端，面积达181公顷，七个山头宛如盛开莲花。这里...',
#  '1061857967': '微雨众卉新，一雷惊蛰始。\n下雨天跟跑步更配！ 杭州·桐庐体育馆(大联路)\n阳光温暖，足以抵抗冬日严寒。 杭州·桐庐县学圣小学\n终于爬起来，跑了个lsd，爽到了。 杭州·桐庐县学圣小学\n跑出了预想当中的节奏，还是要继续加油啊。 杭州·桐庐县学圣小学\n重回第二故乡，陌生又熟悉，没想到会重新看到八一广场的朝阳。 南昌·八一广场\n今天早上也太冷了点吧，还起风了，鼻涕流个不停。继续加油！ 杭州·桐庐体育馆(大联路)\n今天的节奏是跑的稀碎，中途感觉有点岔气了。不勉强自己，早早结束回去休息吧。 桐庐县学圣小学\n起床迟了，内心挣扎不想跑步，所以，要出门跑步啊！时间紧张，少跑一公里了。 杭州·桐庐体育馆(大联路)\n春节假期就要结束，又要回到按部就班的日子。今天早晨起雾了，整个人浸润在雾气中，倍感寒意。  杭州·桐...',
#  '1063255745': '头上三尺不一定有神明，但一定有监控\n 做科研这些年，唯一练就的本领是能够吐得一口好槽 但那玩意儿没用啊\n本来以为这个接诉即办的纪录片只是在北京电视台放一放，没想到居然搞成了电影并且还公映了\n央视自从那个章鱼级的女主播大火之后，似乎一到重大足球赛就必须配一个女主播。但是吧，至少你得看看球、补...\niPhone的广告请了小岳岳，Mini Copper的广告请了谦儿大爷。那些曾经的中高端进口品牌都开...\n昨天看新闻说副主席专门会见了国际奥委会主席巴赫，盛赞巴黎奥运会的开幕式很精彩。感觉，我国现在就是看热...\n奥运会暴露出来最大的问题是：中国（体育）记者水平太低，普遍娱乐圈水准。 奥运会受益最大的人：张雪峰。...\n 夜里做梦，梦见一个准院士级的大佬和我聊天。期间他小声说：“在XXX领域，就算你我加起来，其实也还是...\n 中文自媒体的消息吧，基本上双方都有巨大优势、拥有各类好消息。实在是太逗了。在美国生活关注美国大选我...\n 以前听欧美大佬过来做报告，常常会惊叹于他们的思路：“原来XXX可以这么想啊”、“那个XXX居然这样...',
#  '1065518421': '好看的城市千篇一律？\n欢迎在吉娜小姐身上“薅猫毛”！\n春节前大扫除，我家延续近30年的传统！\n看着眼熟，像新疆的戈壁公路🛣️，也像宁夏的火石寨！\n幸好然爸在家，慌乱中我们双向奔赴，相拥来到卫生间，喝茶！\n然爸的同事很有爱，专门定制的生日蛋糕！是家里的两只小猫咪一起给然爸庆祝生日呢！\n我算按摩达人嘛？ 除了按摩椅每天要午休专用，其他的都打入冷宫落灰啦！每周还是要去按摩馆，个人体会是自...\n然爸惊呼：叮当又打翻一盆花！我下楼一看，花盆里怎么长出一只可爱的猫咪呢！ 叮当已经打翻了三盆花了，总...\n昨晚没睡好，半夜还把然爸摇醒，惊呼：又地震啦！我真切听到轰隆声、感觉到床晃动！然爸说：没有震，睡吧！...',
#  '1066401875': '旅行～其实是路上最美\n小区夜跑比较安全，没吃的\n七月来的⑦仔 银渐层弟弟\n看着很晒吧，实则就是很晒\n我的小室友 它有盛世美颜\n不争不抢，一猫一个水果🛏\n 厦门·47咖喱·東南亞餐館\n喝茶 晒冬天十点🕙前的太阳☀\n关我屁事 关你屁事 且做自己…\n状元 礼品还是我刚准备买的东西✌',
#  '1066707854': 'infj 今日，雨水💦\nまだね 👋🏻上海生活碎片 上海\n她们都有想要守护的明天 infj\n进入到十月 倦怠期持续 做秘密📝计划中\n📝：📷 没人看也会默默记录的生活碎片infj\n两朝三世六百年 好久不见👋🏻故宫 北京·故宫博物院\n好吃(๑>\u0602<๑) 还要再来！ 潍坊·牛四姐·齐齐哈尔大众烤肉铺\n感谢我的靠谱日代 宝贝们漂洋过海🌊 今年A社 毛衣和beams拼接卫衣成功getBEAMS\nLaufey/Spencer Stewart《From The Start》 From The St...\n📝好物分享（自己碎碎念(⸝⸝•‧̫•⸝⸝) 在日本的时候买了它家很多包 什么size的都入坑了 最喜...',
#  '1066889492': '门子哥你搁这端水呢 🙄\n老师我家小雾还在上幼儿园呢\n有多浓，和正门的胡子一样浓吗\n小裙子这么好看是迪*尼公主吗🥹🥹🥹\n天啊…………妈咪的睏睏小狗妹…………😢😢😢\n立本人你们那么爱搞那破限定是有什么治不好的瘾吗\n谁是堺市出生的，我再给你一次机会，谁是，堺市，出生，的\n这个破天真的很烦如果要整理半个月的行李的话从踏马棉衣到踏马短袖都踏马的要踏马的准备\n终于把这个五毛钱就能在t那个b上定制的我连做无料都不会做这么廉价感的破尺子拿到手了 文件夹还不错的',
#  '1068237684': '只要你发现这个人心性不对， 就不要跟他对话，一个字都不要说， 放生即可，交给因果。 —— 弘一法师\n玄学提醒，一定要记住！ 1. 吃饭时，不敲碗不要叹气。 2. 用过的被子，不要送人。 3. 生活中的...\n能让你至少多活三十年的 20个运动： 1、使劲搓手心，搓它个一百次 2、踮脚站立，每次坚持一分钟 3...\n老人言：“炒菜的人，一定等吃饭的人！吃饭的人，则未必会等炒菜的人！总有一些没良心的人，认为你做的就是...\n六合之外，圣人存而不论；六合之内，圣人论而不议；春秋经世先王之志，圣人议而不辩。 《庄子•齐物论》 ...\n01. 为人处世要做到：眼观六路，耳听八方，话留三分。 02. 兄弟不碰金钱，你看不到嘴脸，儿女不到...\n时间，不一定能证明许多东西，但一定会看透许多东西。越来越觉得，照顾好自己，不给别人添麻烦，是成长重要...\n生命力拉满 小幸福短句 1. 生动比漂亮重要 2. 爱的第一页 爱自己 3. 日子平淡 好在我喜欢 ...\n家中三代从商，父亲说，成大事者，没有一个是温文尔雅的。温文尔雅，只不过是放出来的烟雾弹，是精心设计的...\n神脐功：本功法简单易懂，能治百病，可开发特异功能！ 姿势： 站、坐、仰卧均可，全身放松，自然呼吸；两...',
#  '1068691797': '松弛是很了不起的力量\n被剥削者的安全感来自于：还有可被剥削的对象。\n新工View 不是今天的 今天暴雨 但雨后的确又长这样了\n不工作的时间越长 就越觉得工作时的自己太矫情了 忙忙都忙 再忙🈶DeepSeek忙吗\n上一次一口气看完一本书已经是十年前了 从天亮看到天黑 不穿秋裤的双腿跟保温杯里的温水一样 一旦开始失...\n回家这趟打了两次电话订座。 馆子基本上都是本地人会去的， 接到电话都是粤语的喂你好。 听到这句话基本...\n我在此起彼伏的唉声叹气里哈哈大笑 中途经历小孩叫醒爸妈 后排狂揣椅背都不生气 被封神之蓝色风暴的本我...\n昨天早上北京早高峰开始堵了 我因为没穿雪地靴出门躲到星巴克取暖 且因为没有得到金桔拿铁的可爱杯套而难...\n今天吃粥吃到一半下楼买榨菜，电梯门一开，电梯门外全是人，无所事事站在那里也不进电梯。 电梯里的两个老...\n刚下完雪的北京，地面湿滑 好消息：打到同龄司机的车了 坏消息：正在播放初中时期的QQ音乐 现在就是一...',
#  '1069139841': '喜欢吃🦐的一定要收藏\n清蒸鳕鱼的关键是什么呢？\n喜欢吃🦐的一定要收藏起来做给爱❤️\n西兰花🥦保持翠绿的秘诀就在这支视频里\n来日本🇯🇵只有第一次和无数次 日本 日本·东京\n超长下饭日本药妆店购物分享，主打好用平价高性价比\n无竹令人俗，无肉使人瘦。若要不俗也不瘦，餐餐笋煮肉\n三月的雨是南京最温柔的修辞学家—— 写字楼玻璃淌下的银线将霓虹晕成青绿光斑， 老门东墙头的凌霄花攀着...\n “作为一名南京人，对鸭子的要求真的很高！🦆 自己动手丰衣足食了！这不，盐水鸭就安排上了！🔥 南京的...\n 春日繁花迷人眼 你却如玉缀枝头 半倚谢庭半倚梦 幽幽清芬迎风娇 许是昨夜雨儿撒了欢，落了一地俏 上...',
#  '1069617570': '胸有惊雷而面如平湖者可拜上将军。\n在《白塔之光》里看到了久违的小武王宏伟，生活流表演艺术家，站在那里不用演就是角色本身了。\n又看了一遍《时时刻刻》，这一回，对于片中几位女主角对于各自人生的选择，对于生命中每一个时刻的度过方式...\n大脸李不愧曾经的800多万粉丝的科普大v，口头表达能力非常出色。 上一期共50多分钟，第三期10多分...\n打开B站《了不起的盖茨比》（2013），发现共有79人同时在看，算是我最近打开的电影中，同时在线观看...\n小李子、凯瑞·穆里根，托比·马奎尔2013年主演的《了不起的盖茨比》看完，怅然若失，电影呈现了一个盛...\n开车路过一整片花林，二话不说靠边停车大拍特拍，心里不住感叹：这就是春天啊，你们这么热烈又寂寞地盛放，...\n《苦尽柑来遇见你》第一集，明明看起来就是平平无奇的穷苦人家的故事，似乎所有的情节都不意外，但就在这明...\n也不是有什么所谓道德洁癖，但在影视剧看到年轻人因为一时的小聪明得逞而兴奋不已得意忘形时，做为中年人总...\n《混沌少年时》第二集是警察第三天到学校进行走访调查。于是男孩、女孩的朋友们陆续上线，也包括督查15岁...',
#  '1070214220': '2024年的最后一个日落\n昨天在影院观看《蛟龙行动》，不仅电影好看，而且影院也很有特色！\n远看山有色，近听水无声。 春去花还在，人来鸟不惊。 ——唐·王维《画》\n人过五十后，要学会让自己高兴，放下恩怨，名利和焦虑，定期清理不需要的东西和人，享受简单的生活。\n其实人生最忌讳的就是不知足。天道忌满，人道忌全，月满则亏，水满则溢。因为一切的规律就是盛极则衰，物极...\n生气就是在生病。千万不要把太多的负面情绪压制在自己的身体里，情志不畅百病生。人不是老死的，都是气死的...\n女孩子选对象: 1，善良人品好 ， 2，能担责任， 3，不能有暴力倾向， 选对了一生一定会健康 ！幸...\n渔家傲·雪里已知春信至【宋・李清照】 雪里已知春信至， 寒梅点缀琼枝腻。 香脸半开娇旖旎， 当庭际，...\n婚姻，从来不是感情的纯粹联结 我们总爱讲"贫贱夫妻百事哀"的故事，但现实是：婚姻从来就不是纯粹的感情...\n辩证治疗，到底是“肾阴虚”还是“肾阳虚”，怎么辨别? 【阳虚体质】 1、冷热——怕冷怕风，手脚凉 2...',
#  '1070437773': '绘食小筑[超话]第一眼早餐天天晒早餐#\n绘食小筑[超话]第一眼早餐早餐打卡记录美好生活今日早餐#\n天天晒早餐周六工作日今日早餐长这样周六早安工作日的早餐今日早餐推荐#\n第一眼早餐今日早餐长这样今日早餐记录今日早餐推荐生活需要仪式感今日早餐分享天天晒早餐#\n跟着木姐做早餐吧[勾引] 早安，早餐 周一好[爱心] 新的一周开启咯，六点半出门天已大亮，天气放晴回...\n跟着木姐做早餐吧[勾引] 早安，早餐 周三好[庆祝] 今日天气有些湿热，春养肝，晚上先踩会单车，洗漱...\n跟着木姐做早餐吧[勾引] 早安，早餐 周一好[玫瑰] 新周开启，天气阴沉，一到白水带就开始下雨，拖着...\n跟着木姐做早餐吧[勾引] 早安，早餐 周三好[玫瑰] Hi，今天一出门就看到红日，瞬间觉得心情舒爽，...\n跟着木姐做早餐吧[勾引] 早安，早餐 周一好[爱心] 又开启新一周做牛马的日子[庆祝] 每次出入小区...\n跟着木姐做早餐吧 周六早上好[爱心] 广东一夜入冬，昨天还有30度穿短袖，今天~~[破涕为笑][破涕...',
#  '1070580505': '我操这个鬼子咋这么帅\n周五周五周五假期假期假期\n自拍还挺帅直播怎么感觉脸又肿了\n西八蛋糕狗崽子你不能这样对我啊\n竞丝现在不带bin语从句不会讲话\n就周末回家都好难受。。真的不想回来了\n换了新手机却没有去看con。好悲哀的事实\n集了两个三十赞结果抽出来两个谢谢参与 再也不赌了\n花公司的钱也是吃上贵点的外卖了 这从餐具的包装就可以看出来\n今天组长夸我的卫衣颜色好看，终于给我机会超经意露出这件是联名款了😌',
#  '1071833050': '打卡金象城鸽味轩，老广的菜品就是太精致了… 不够吃，又加了两个菜… 南京·鸽味轩(金象城店)\n新入手的电动牙刷，昨天才下单的今天上午就到货了… 中午的时候，爸爸骑电动车送到了厂门口给我… 差不多...\n晕死，大中午的居然被喊来加班了… 带着那孩子打车一路狂奔回妈妈身边，一进门妈妈准备了她和爸爸昨天做的...\n打卡，签个到… 经典手冲——卢旺达玛舍莎，浓郁的果香和糖渍的味道，好喝… 南京·星巴克臻选(南京金象...\n 起床、上厕所、称体重、洗漱、做早餐… 礼拜二了，气温继续上升有点夏天的感觉了，我已经开始穿打底衫+...\n 起床、上厕所、称体重、洗漱、做早餐… 礼拜三了，小周末… 居然有蚊子了… 下半夜的时候一直在我耳边...\n早餐 礼拜四的清晨… 今天气温些许回落了，今天吃个高蛋白质的早餐吧… 今日份早餐一人食：烤鸡胸肉+半...\n早餐 礼拜六的清晨… 今天加班，已经和爸爸妈妈约好了中午一起去吃牛排了… 所以，早餐就简单吃点吧… ...\n早餐 礼拜天的清晨… 今天值班，中午要和爸爸妈妈一起出去吃牛排… 所以早餐简单吃点吧… 今日份早餐简...\n早餐 礼拜一的清晨… 新的一周开始了，吃个来自妈妈的爱的早餐吧… 今日份早餐一人食：妈妈做的鹌鹑蛋牛...',
#  '1074149892': '*散步* 今日之沈阳\n*续* 节 还得过…… 续上！\n*沈阳* 韩餐 + 西塔 = 半日沈阳\n*生日* 时光不弃 岁月留痕 生日快乐 欢喜感恩\n*年* 花卉市场 年味 被一丛丛新鲜绚丽簇拥着这不就来了么\n*那时* 无意中看到这个 - 童年的后京畿道 满满的记忆 深深的怀念\n*散步* 又刷中国工艺美术馆 如此奇妙的想象力、创造力，人工智能？切！\n*沈阳* 帅府 - 有谁知道为什么书房挂着《菊花赋》？ - 赵四小姐怕是从未曾踏足帅府吧？这倒好，在...\n*庙会* 龙潭庙会 民俗展示已不多见 主办方用心了 懂的人虽不多 已实属不易 听见身边年轻的北京爸爸...\n*又……？* 近几天连续收到境外可疑来电…… 号码被出卖了？ 因为国外有朋友，不能设置拦截所有境外来...',
#  '1075196254': '当清晨的第一缕阳光洒落，我们已骑行在路上。风在耳边轻轻低语，车轮在脚下欢快地旋转。感受生命的活力和前...\n谢霆锋依然这么帅呀！这么多年真的一点没变 这么精彩的动作戏、追车戏和枪战戏，让我找回了怀念的许多年前...\n早晨骑行曹妃湖，往返37.39公里，均速19.42公里/小时。夏练三伏，入伏了总得出点汗，现在选择早...\n“我是个普通人，能把我变成战士的只有我在乎的人。” 杨妞花的演讲《这不是我一个人的复仇》，让我泪流满...\n如何做到不瞎操心，更显年轻呢？我总结了20 个好习惯，希望能对大家有所帮助： 1. 分清“自己的事”...\nJD宣布为外卖骑手缴纳五险一金！ 骑手们的春天来了！🌟🚴♂️东子这次真的走心了！ 💪 继快递小哥之后...\n低调，才是人生最大的智慧 在这个物欲横流的社会中，炫耀似乎成了一种“潮流”。人们总喜欢通过展示自己的...\n清晨梳洗时发现鬓角的白发倔强地翘着，像根扎进时光土壤的银针。 镜中那张熟悉的面孔悄然爬上了细纹，恍然...\n春天来了，北方的花还没开，去河边看看柳树抽芽，顺便带着一杯沪上阿姨的血糯米奶茶，选择零卡糖哦，一路走...\n令人释然的一段话：人不能一直过很省钱的生活，刚开始省钱，很开心很有成就感。虽然省钱能存到钱，但是舍不...',
#  '1077051714': '上班吧！一堆事儿呢！\n吴磊 来，么一个！ wl\n吴磊 温暖人心的几个字，是我担给的正能量！\n吴磊 互联网不是法外之地，每个人都要为自己的言行负责！支持维权！\n我是一台“冷酷无情”的生产机器！ 卡砖框架✔️ 有空装饰一下就好了！\n吴磊 敬业的女工！做到半夜！终于做完！以后美美的小卡不用收起来，每天一换！ wl wl\n吴磊 00：00 都在等待这一刻！ 等待这个qsjzsdnr 的生日到来！ 这几天堪比过年一样热闹和...\n 我发誓，我再也不给自己挖坑了！以此条微博为证！ 练手的12个磊牌全部送完！！自己也没记得留一个，真...\n吴磊 关于4月【这又双叒叕……是一条抽奖博】 属于磊磊与蓝莓🫐们的浪漫一一“磊磊信”！永远可以相信这...\n收到打印机老师 的丝巾啦！好漂亮！ 球球老师笔下的磊磊真的唯妙唯俏，出神入化！ 佩服得五体投地 ！我...',
#  '1077152315': ' 风起洛阳 原图直出\n 记录秋天 北京·大观园\n我和臭图图 乌兰察布·兴和\n能不能别这么胖了啊，能不能，，，\n臭宝回来还没有发过照片呢 麻辣烫真好吃😋\n远赴人间惊鸿宴 老君山山上吃泡面 洛阳·老君山\n看表演 吃饭饭 今天逛了博物馆，太好看 图片太诺选不出来 洛阳\n一直好奇一件事情 武侠剧行走江湖的侠客们没有钱是咋解决衣食住行的啊\n结束了，一切都结束了，好多话想说，又不知道如何说…… 爷爷一路走好(补记录11月28号)\n跨年♥ 加班完，刚好看一场跨年电影 商场吃饭店铺虽然都关门了 但我们有小卖部呀 小时候的味道真好 2...',
#  '1078527881': '新年江边走，四季样样有。\n蔡宏伟朗诵“生存与毁灭”朱生豪译文\n早春里的夏日午后，挥拍流汗，不负蓝天不负暖日。\n抓住“乍暖还寒”中的“乍暖”，挥挥拍，活动活动筋骨。\n两个日耳曼男人，外形同样俊朗，内心一般阴暗:背叛自己的祖国。\n如果布置一道微作文:各用100字描写梅洛尼与谷燕端详马斯克的眼神的内蕴，能写出什么样的不同？\n【宏伟说史】以欧阳修为参照体，蔡襄不过一篾片而已 纪录片《蔡襄》对蔡襄捧过头了！彩虹屁太多，涂抺多了...\n立春过后，属于最江南的地方，尚未听得到春天到来的脚步声。梅瘦枝头，水寒池上，偶尔惊起掠过的小鸟，也是...\n【宏伟屐痕】公历的三月第1天，一家人去奉化西坞的金溪源头，先看过了盛花期的梅花，在花瓣簌簌飘落中，感...\n于健身而言，挥拍运动远在跑步、游泳之上。拍子时时会损坏，挥拍的胳膊肘常常要酸痛，挥拍的人终将要老去…...',
#  '1078767480': '做自己的心理医生-查尔斯\n男人的觉醒时刻，绝对在35岁之后！\n西电东送：纵横中国的能源“闪送”工程__中国政府网 西电东送：纵横中国的能源“闪送”工程\n关于组织申报2025年历史遗留废弃矿山生态修复示范工程项目的通知_国务院部门文件_中国政府网 关于组...\n35岁以后，男人理想都去哪了？答案很扎心！——查尔斯 www.toutiao.com 2025-03...\n成年人最体面的活法：不讨好任何人—查尔斯 🌙 最近突然发现 手机相册里堆满了工作文件截图 却没有一张...\n为什么说，你和曾经的好朋友，已经走散了？——查尔斯 我们好像都病了。 在大城市的钢筋水泥丛林里，每个...\n在外漂泊的游子，追梦路上你还记得家的味道吗？——查尔斯 深夜里，当写字楼最后一盏灯熄灭，你拖着疲惫的...\n心理援助不等于“软弱”，把握好孩子的学生时代?——查尔斯 深夜的教学楼走廊里，十八岁的林然攥着月考成...\n探索：你身边那个命中注定的人！——查尔斯 在心理学家的实验室里，曾有一组被试者持续三年记录让他人感到...',
#  '1081575921': '开心… 又赶上了大站车\n很喜欢华为天气的这个板块\n北京开始刮风了吗？上海也快了\n是不是每一家都分配了一个失业名额？\n瞄了一眼衣柜…… 去年买的短袖都得更新……\n最近泡在了公园里…… 如此好的春光不能辜负呀~\n10几年的往事涌上心头… 这一刻我知道，一切都是倒计时了\n…………… 楼下小孩撕心裂肺的尖叫和哭声……… 头皮发麻…… 倔起来撒泼的孩子太可怕了\n炒河粉心得： 500g河粉，要放3个鸡蛋……… 还是没有炒出小店里的味道…… 不知道哪里出问题了……\n多日下厨后的心得：虽然解锁了很多新菜：炒合菜，豆腐肉末，鸡汤，荷兰豆香肠，醴糟鸡蛋汤，海带，韭菜饼，...',
#  '1082442251': '理想同学来作画，绘出女神节日新祝福！\n松开双手，走下汽车，停车场离车泊入，零接管轻松拿捏！\n一个小小设置，就能给她带来充满安全感的幸福瞬间，设定属于她的理想生活\n优秀车机，懂我所想，当我说出前半句，通风座椅、座椅按摩、刷洗车窗……就已备好\n六座车型因为中间有过道，加个储物篮、储物箱，就能把空间利用起来，多一处储物空间，很实用，包好用呢\n两年前，那款被大家亲切称为“冰箱彩电大沙发”的理想L9正式上市，如今已走过两载春秋。然而历时54个月...\n之所以选择理想六座车型，主要还是看中了它的实用性和舒适性，也能够轻松应对多人出行的需求，2+2+2的...\n如今新能源汽车的智能化已成为不可或缺的一环，理想汽车的小主人模式，为孩子在旅途中带来了欢乐时光。而视...\n理想同学APP正式上线啦！随时随地陪伴的智能助手，解答我的各种问题。拥有的视觉感知能力，陪伴一起看世...\n理想同学刚刚陪伴过完了春节，现在又来一起闹元宵啦！肯定有很多小朋友对元宵节还充满好奇，元宵节有什么寓...',
#  '1084097140': '蒂尔达·斯文顿也太迷人了。\n人都快头七了，网上还没掐完，我看都看累了\n我女儿有两个妈妈——一个是我，一个是我妈。而且我妈坚持要比我更有妈妈的优越感。窒息。\n作为自己过得一地鸡毛的已婚妇女，真心觉得全情投入地看别人家的一地鸡毛的同学们太有活力了。\n看关于珠撞海人的帖子，看到一个写母亲在第二天天人永隔的，为人子女真是能感同身受这种撕心裂肺；看到另一...\n低端影视真是绝了。。现实中的首尔之秋刚落幕，ta们就把《首尔之春》上传了。其动作之迅速，行动之应景，...\n小区的家宴中心昨天开始传出音乐和歌声，要不是唱得太难听我还以为有人开派对。从阳台定睛一看——有花圈。...\n猫猫太爱我有时候也令人为难。比如在我要从马桶上起来时，它还在我的腿上踩奶；比如我举杯喝水时，它来撒娇...\n虽然我是85前，但我并没有粉过大S和《流星花园》，甚至觉得《花样男子》这个故事就是个逻辑不通的白日梦...\n昨晚上和女儿同学的妈妈打了一个电话，令我心态都有点失衡。就是那种挣扎过的倒霉鬼遇到锦鲤附身笨蛋团宠的...',
#  '1087153531': '生活是一个动词 嘉兴\n被人当面蛐蛐该怎么反应\n满眼的绿色，是最爱的夏日啊\n芜湖～对我的新衣服表示很满意\n哎呀～又年轻了一岁 祝我生日快乐吖\n是春天了呢🌿 洋甘菊开得那么浓烈🌿🌸🌼\n黄酒乌篷船🛶 绍兴醉江南🍶 绍兴·鲁迅故里\n🌤有阳光🏝有山风 还有🦙🦌🌿 宁波·达蓬山星梦乐园\n“喜欢安于现状，也对未来充满希望” 祝愿我们平安健康，顺顺利利！\n翻出去年的今天，我真的太喜欢宁波了，满眼的绿就算了，不急不缓的节奏还有那么多的美食太让我喜欢了',
#  '1087885304': '舞斗的不错，下次继续\n在黔西南每天实现薄荷自由 兴义\n理解纣王，成为肘王 珠海·长隆海洋王国\n又来看文艺阿姨 北京·中国电影资料馆艺术影院\n韭菜煎饺，鲜虾肠粉，潮汕毒药，歪瑞奈思 广州·珠江新城\n超级意大利复兴是济南人民的大食堂，一共23元。 济南·超意兴快餐(智慧店)\n临时决定的周末南下，宁波好吃！😋😋😋 午后还逛了中心菜市场，看到了传说中的宁波三臭 宁波\n凉都早起，来唆一碗羊肉粉，单加的羊肉竟然是带汤的一碗用大量香菜做底，鲜，油辣子也好脆好香！ 六盘水·...\n最近在进行xx面试，一道经典问题是，既然申请这里，那么对几位老师有多少了解？哪些老师的研究吸引你？然...\n这周末要去L校参加一个国际会议，之前投稿投的是全英文材料，回执登记的报告语言是英文。结果最近议程出来...',
#  '1088970475': '“卧薪尝胆，厚积薄发”\n就这一刻 多晒太阳💫✅减少烦恼 汕尾\n你并没有迷失，你只是处于这一进程的早期阶段 \n“如果你生命中发生了不愉快的事情，你应当变得明智，而不是觉得受伤”\n一个人要拥有不结婚的能力，才能具备结婚的能力。独立成熟的人，才能更好的去和另一个人依赖。 ——马戈·...\n所有一切都是你一定要去经历的过程，由不得你喜欢或者不喜欢。水来就水来，火来就火来，面对一切都要心安理...\n阅读这事儿之于大脑就好像跑步或者撸铁之于心脏和肢体，都只不过是 “锻炼” 而已 —— 健脑和健身本质...\n5 年后你会成为什么样的人取决于 - 今天吃的食物 - 今天学习的技能 - 今天读的书 - 今天养成...\n我喜欢平静的人。TA们从不高声喧哗。TA们不是为了炫耀而活，而是以一种安静平和的方式存在，努力不去主...\n做一个平凡的人，在世间悄无声息地来来去去，在外面和自己的心灵里无拘无束地徜徉，享受一切闲暇和孤独，注...',
#  '1091938325': '打个球受凉了，醉了🥴\n 哈[种树][小繁花][好运连连]\nHello～2025～[2025][气运之子]\n❤︎ 𝑯𝒂𝒑𝒑𝒚 🐍𝒀𝒆𝒂𝒓"新年快乐，新年行大运" [封神第二部]\n 添福卡惊喜开奖！巳巳如意，蛇年福星当属我~ 成功开出 送出的1.28元福运红包，新年一定“蛇”么都...',
#  '1092200012': '近期的小日子🥤🎭 💊\n最近上班的快乐源泉 🍉\n[招财超崽]一些7788\n 真的 居家办公居不起就别居\n上班赚钱，赚钱看病，看好病上班\n正宗的食其家可真好吃顶饱（嚼 ）\n宇治尊嘟太美辣！！！ 日本·宇治市\n 我的评分： 心动的信号 诈骗的信号\n[招财进宝] 愿我日进斗金哈哈哈哈哈哈哈哈哈\n友友们这个是骗子不要相信，请举报拉黑！！ 靴靴~',
#  '1092758207': '左侧大脑前动脉A2取栓术。\n病人头痛，脖子僵硬，头颈部不敢触碰，她自认是在外面做针灸导致的，我去看她的时候她正在微信和针灸医生交...\n今天算了遇到高人了，他29岁，接近2米的个头，昨天早上起床时眩晕发作，中午午睡后再次发病，妥妥的耳石...\n上午连续三个病人都是耳石症，第一位是右侧水平半规管管石症；第二位是左侧后半规管耳石症；第三位是右侧水...\n连续10多台手术，做完最后一个急诊病人已经是凌晨1点过，回到科室看到还有医生在“挑灯夜战”，她是规培...\n他30岁，上个月因耳石症找我复过位，这个月又发病了，三天前（周二）找我复位，他是右侧水平半规管管石症...\n昨天规培学员让我看看新来的眩晕病人，女病人50多岁，根据她的叙述貌似耳石症，我于是给她诱发检查，她一...\n他也是眩晕找我看病，来的时候还晕着，脸色苍白，有右向自发性眼震。他是在早上起床后做操的过程中发的病，...\n下午看了36个病人，其中有6个耳石症患者：一个已经自愈，一个是上周五复位后来复诊的，不需要复位了。另...\n下午我提前半小时就出门诊了，已经有了等候的病人，前面三个都是外地来的患者：第一位是耳石症患者，一月前...',
#  '1094901057': '赵心童在斯诺克世锦赛预选赛4：0暂时领先\n希金斯获得斯诺克巡回锦标赛冠军 希金斯10：8胜塞尔比，希金斯获得冠军，塞尔比屈居亚军。\n，全球首张无人驾驶载人航空器运营合格证（OC）正式批准发出，亿航智能成为全球首个集齐“四证”、具备无...\n赵心童在斯诺克预选赛抽签表情况，赵心童若晋级正赛，需要连续内卷中国球员 第一轮：赵心童对战张家玮 若...\n预计暴雨和洪水将在严重积水的南部和中西部地区再次发生 美国肯塔基州霍金斯维尔） - 预计周六在南部和...\n美国纽约）——贸易战引起本周华尔街的大多数数据都是亮红色的，但并非全部。 关注食品、医疗保健和其他生...\n斯诺克世锦赛22名外卡名单 赵心童 高阳 莱昂·克劳利 史蒂文·霍尔沃斯 利亚姆·海菲尔德 弗洛里安...\n日本千叶县发生5级地震东京等地有震感 中新网电据日本TBS新闻网报道，当地时间7日9时52分许，日本...\n波多黎各圣胡安）——多米尼加共和国首都一家标志性夜总会的屋顶在一场梅伦格音乐会开始近一小时后倒塌，导...\n美周三宣布暂停数小时前生效的所有“互惠”关税三个月一只有一个例外，这加深了旨在瓦解世界两个最大经济体...',
#  '1094994871': '孙中山的故事（九） 文/代明\n孙中山的故事（十二） 文/代明 十二、同盟会诞生\n陈懋鼎 1886年，当时还是16岁的陈懋鼎，陪同大伯父陈宝琛一行去鼓山游玩，所获颇丰，于次年写下一系...\n我的工厂经历（15） 六、吴凤鸣 说起和我同来的那些工友，有一个人的名字不得不提，他叫吴凤鸣，是我在...\n金领丽人梅凤玲（五） 记得我在集团战略发展中心工作期间，派我到平安北京分公司，帮助他们推动团险销售体...\n孙中山的故事（三） 文/代明 三、智斗人贩子 孙中山童年时代见闻过社会许多不公平的现象，这些现象深深...\n孙中山的故事（八） 文/代明 孙逸仙大夫 \ufeff 在澳门一条狭长平坦的石板路上，一个身穿白长袍的英俊青年...\n孙中山的故事（十八） 文/代明 十八、广州遇险 ，孙中山在广州观音山越秀楼就任非常大总统。新政府成立...\n我的工厂经历（18） 八、工会之家 很难想象，在我们这个充斥着黑暗、肮脏、劳累的地方，还会被“工会”...\n今天，刚得到一个最不好的消息，我人生中最重要的一位贵人，如今患上肺癌晚期，已是生命垂危，可我不但帮不...',
#  '1097506317': '周一，早安☀️ 湖州\n黑鱼面…… 湖州·南浔古镇\n跑步是克服慵懒的良药…… 青岛\n逛吃的一天……每一天都值得庆祝🎉 青岛\n回家🏠青岛再见！ 青岛·青岛胶东国际机场\n保持乐观积极的情绪，逆着阳光，一路向前吧！\n愿你所有的努力都有收获，加油吧！ 湖州·南浔古镇\n心里有光，慢食三餐， 白白胖胖，充满希望。 湖州·南浔古镇\n晨跑打卡，坚持锻炼给自己一个好身体…… 湖州·湖州南浔希尔顿酒店\n人生路上常有风雨，需要一个好的心态。再难的路，只要不放弃，一直走下去，总会走到终点；再不顺的生活，撑...',
#  '1100949262': '每日健康问答|春天如何疏肝解郁？ 作者：宣磊 王景 中医认为，春应肝，肝属木，主疏泄。雨水过后，冬寒...\n每日健康问答|总戴假睫毛影响健康吗？ 作者：张琪 假睫毛本身的主要成分是合成纤维（比如聚酯纤维），目...\n每日健康丨做“足”功课，远离糖尿病足 作者：钱志敏 佘敦敏 陈怡文 王蓉 年过七旬的王女士患有糖尿病...\n每日健康问答|女性各个阶段要关注的健康问题都有啥？ 是国际妇女节，北京市海淀医院妇产科副主任医师倪俊...\n每日健康问答|慢性肾脏病患者的八大“黄金法则”是什么？ 作者：李贵森 肾脏是排泄体内废物，维持体内水...\n每日健康问答|芹菜和洋葱能帮助降血压吗? 高血压是常见的慢性疾病，流行病学调查也显示，几乎每4个成年...\n每日健康问答|脂肪肝患者如何减重？ 脂肪肝患者应循序渐进的减重。 一、先确立目标 减重超过现有体重5...\n每日健康问答|睡眠不足有哪些危害，如何提升睡眠质量？ 人每天有1/3的时间在睡眠中度过，睡眠不足有哪...\n每日健康丨每天吃一小把南瓜籽，竟有这么多意想不到的好处 作者：薛庆鑫 炒熟的南瓜籽不仅口感香脆，营养...\n每日健康问答|花粉浓度高，如何做好防护？ 花粉过敏又叫花粉症、枯草热，主要是由于对植物花粉存在过敏现...',
#  '1105438484': '，农历二月初四，星期一。 暖高中二年级春季学期开学。\n，农历十月二十五，星期一。早送暖，休整。 10点起床，和妈一起吃饭。 11点和妈洗澡。 13：30开...\n，农历十一月（冬月）初六，星期五。 早送暖，休整。 今天特别记录：在2024年的大雪节气把夏天的鞋换...\n，农历十一月（冬月）十六，星期一。 休整结束启动，路上的天、水、桥。 分享单曲 Colors Of ...\n，农历十二月（腊月）初一，星期二。 早送暖，天色是深夜。 2024年倒计时了。 分享单曲 蓝色时分 ...\n，农历十二月（腊月）初六，星期日。 【今日，小寒】①今日10时33分，将迎来2025年第一个节气小寒...\n，农历十二月（腊月）二十二，星期二。 音体美支撑着度过了高二上学期，以校舞团成员参加2025年新春音...\n，农历正月初八，星期三。 今天是上班日。 用连续时间看部好友推荐的1995年出品的电影，荣获第68届...\n，农历二月初六，星期三。 昨日下小雨雪。 今天和妈每周一澡。 【今日，惊蛰！】①今日16时07分迎来...\n，农历二月二十二，星期五。 早送暖，9：00早场家政结束。休整到13：00，起床早午餐。15：00继...',
#  '1105753990': '这就是降息的力量吗？\n一口气睡了5个多小时，真的幸福\n我说过，30岁之前拿下注会，不是问题\n我的天爷呀，抢购的人你们钱都是从哪儿来的？\n开小会，研究重要的事，一下午，缺氧，头晕眼花，爱咋咋地吧\n卧槽，本不富裕的家庭雪上加霜。我都好久没有打开过财新了，这又自动续费一年！\n手头工作结项了，转正流程办完了，清明假期的票和酒店也都订好了，摸鱼摸鱼~坐等放假！\n苏州经济能发展这么好，一定有他的道理！ 就一个简单进厂打螺丝的工作，就能够给到这样优渥的条件和待遇，...\n我以前不歧视学历，认为能到一起共事的只有谁比谁水平更高，学历只是一方面。但我现在发现，学历低的人确实...\n在地库散步我忍了，在地库遛狗我也忍了，踏马的好几个老人居然在地库溜娃？！！一拐弯车头前站个刚会走的小...',
#  '1107393751': ' 祝你成为很会赚钱的女性\n📖 沧月 |《朱颜》 1.心地善良的孩子，长大了都会是大美人呢。这是天神赐予的礼物。 2.无论是谁，...\n一个人， 用砂锅煮了一锅汤菜： 有淮山、胡萝卜、彩椒、青菜、肉丸。 装满一碗， 连菜带汤一起吃完喝光...\n凌晨四五点时被左眼痛醒。 第二次被痛醒时看了下时间—— 五点五十八分。 左眼术后， 确实偶尔会涩痛，...\n有担当，有交待，敢承担， 这是做人的根基和内核之一，是人的根本之一。 根基和内核稳定，人才不会轻浮、...\n 思想文化上，几千年的“男尊女卑”； 体格力量上，男人大多强于女人； 所以，世俗眼光中，怕老婆是没本...\n年初三。 今日哪儿也没去，因为母亲生病了。 据说年初一晚就烧了一晚，年初二在极不舒服的状态下陪我们去...\n大年初七，返广。一路堵车。 现在21：20，还在大广高速上，刚过了从化，到家大约得22：00左右了。...\n2025.02.14 ，正月十七，周五 情人节快乐！ 看日历想知今夕何夕，上写“情人节”。今日是个好...\n 2025年D8 蒸腊肉，蒸香肠，蒸扣肉，淮山炒西芹，水煮青菜 的中餐， 以及—— 男孩女孩的晚餐 ...',
#  '1107457442': '好想抱抱这里的小水呀\n这一段的配乐真是仙台有树全剧最适配最舒服的一段了\n“这些失去的记忆，也许就快回来了”的另一种表达是，我好像已经再次喜欢上你了\n她说的话我不信 我只听你说 谁懂这句话的含金量啊 完美戳中我 苏易水和沐清歌真的好配好配[招财进宝]\n沐清歌要恢复记忆就全部恢复记忆行不行啊，凭什么让一个只有一半记忆的薛冉冉连苏易水的过往都不知道，就在...\n突然想到 苏易水失忆的话，是不是相当于十九岁的沐清歌在和二十岁的苏易水谈恋爱呀 [哪吒嘟嘴] 开心 ...\n涵之怎么回事 前面沐清歌都演的好好的，怎么到了哭戏这里崩成这样，配音这一段也不贴脸 明明是最期待的一...\n大半夜的戒断反应上来了 看着相册里录频的每一个戳中自己的小片段真的想哭 有仙台有树陪伴的2月真的很幸...\n风月不相关导演居然是陈嘉上啊 又恍惚了我 陈导 给我拍爽姐牡丹一样再给我们为子拍出个人生角色好么！ ...\n 只知道邓为会精装修所有他演过的房子 感谢邓为对涂山璟的用心演绎 好希望邓为继续精装修我的房子 云中...',
#  '1107968550': '陪椰蛋过着惬意的日子\n💻｜假期结束 继续开启打工模式\n生活是个动词 幸福藏在生活点滴里\n🇭🇰｜不想走路的每一天！！！累晕！\n毕业后回家工作的周末生活 xinghu～\n🎞️｜再次流动的时间 是胶片送给我的礼物\n愿 凤翥鸾翔 山遥水长 ·甲辰年十月初二💐\n【杂】给遥过生日 带儿去玩 在家做了胖乎乎的肉包\n🐍新岁启封 欢迎我的本命年 是椰蛋来家的第一年 是我们一家三口的第一年\n🌊｜风从东海吹到了黄海 第一次带椰蛋出游 和爸妈一起自驾了青岛 从浙江逃离黄梅天 一路北上 天气越来...',
#  '1110290707': '我想要什么都会得到的！！！\n颓废了两天的下班时间 今天终于干点事了\n我真的很喜欢吃 更想能给自己吃瘦还不委屈嘴 带饭一周我看看先\n我是随着年龄增长觉得认识的男的都可以了解下 考虑考虑的 但是确实进一步接触的没有\n我发现我每天注意力最集中的时间段就是下午5-7点，我可以每天只上这两个小时的班吗啊哈哈哈！\n我之前6点下班的，而且住的离公司近，公司地址也好，举例几个商圈也仅，所以下班经常口语约个饭啥的，不管...\n曾经萌生过的一些想法最近又开始蠢蠢欲动了，自己想做的事情越发清晰，都是我自己感兴趣的，自己喜欢的就是...\n穿紧身一点的衣服就能push自己管住嘴一些，比起宽松的休闲裤。。 我搭子又偷着减肥啊哈哈 真能忍啊 ...\n昨天有感而发的 我最近喜欢螺蛳粉远超过火鸡面，火鸡面退出历史舞台吧！！ 真的老在外边吃，就会趋向于越...\n按照古人的记载，晚上不该吃饭或者吃多的，尤其都八点这个点，所以我有点犹豫，是在公司楼下附近随便吃一口...',
#  '1110445910': '云蒸霞蔚 苏州·西山岛\n吹风、听鸟、捞鱼、看野鸭子的一下午。\n母婴好物大赏 🌿【减少肠道负担，提高吸收率】🌿 妈咪爱-敏复健活菌型益生菌， 含有木瓜酵素，帮助蛋白...\n站在山顶俯瞰整片森林，总觉得自己的树不够高耸枝叶不够繁茂，可你知道吗？森林里最高大的红杉需要三代人的...\n 普通家庭对女儿最好的托举是：承认她的主体性，让她有平等的教育机会。撕掉"性别剧本"，将她当"人"而...\n药是有形的，只能治疗有形的病，但现代人的病大多从无形上得，所以，如不从无形处下手，还是无能为力。贪则...\n养生分三个层面：肉体、精神和魂灵。医药只能部分地解决人肉体层面的问题，而更大的问题在于养心和养神。如...\n肝在变动为握，指肝气病变表现在手的握力上，比如手没劲，或者是抽筋、肌肉痉挛等。心在变动为厥，厥指四肢...\n女人的悲剧不在于她是女人，而在于她被教导去从爱中定义自己！社会规训将女性价值缩进婚恋模具，使其自幼将...\n心主血脉，血液的流动是心气推动的结果。血脉也就是我们所说的血管，所以血管的状态是由心脏决定的。如果心...',
#  '1111012245': '谁懂一开年就让我忙晕\n在锅包肉给我托梦之后\n到底是哪里能看光渊了\nplog 一小时两菜一汤\n从今天开始 哇达西要在微博写日记✍🏻\n工作日全妆的含金量不用多说 plog\n仰卧是春天的姿态 只要躺着便能拥有春天。\n日常碎片plog，阳光很好，心情更美🌞🌹 日常碎片\n陌上花开，可缓缓归矣。今日美食与萌宠，岁月静好。🌸🍲 美好\n家后院的“小森林” 每日观察野花野草🌿，享受这片宁静。 宁静',
#  '1111256375': '我不想活了，我想一头撞死\n？？？？？？？？？？？？？？？\n求求了一会千万别让我白跑一趟好吗\n咋回事啊今天，哪跟哪啊都我明天上午还两节课呢\n到时候让我发现没有一个组是自己配的音我就把你们杀了\n这个学校跟谈对象似的总是要问你爱不爱我…别老问这些下头的问题了\n我终于！！又可以做指甲了！！赶在出去玩之前做上指甲了爽啊啊啊啊啊啊啊啊啊啊啊啊\n真是有病啊。。自己语气就是有问题不知道吗谁一天天不烦啊，一点开直播都不知道发生啥了听你训粉听了二十分...\n嘿嘿嘿嘿嘿嘿我又要给人当狗了嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿嘿哦耶！！啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊...\n因为书太多放不下了，为了腾地翻出来了我的十多本剧本和和一堆报名表，虽然啥用也没有但是每次要扔都没舍得...',
#  '1111338183': '申阿婆 上海·光华路\n想更好 更完美 温州·五马步行街\n想要权力又不想有压力 这是多可笑的事情\n哈哈 今天晒一晒我的大额头 宁波·天一阁·月湖\n没有动态的日子是因为睡醒就在上班 西安·西安国际会展中心\n吃饱喝得 奔赴下一战场 深圳·陈鹏鹏潮汕菜(壹方天地购物中心店)\n喜欢的东西依旧喜欢，但不执着于拥有，尊重缘分 懂得释怀！ 深圳·东门步行街(新园路)\n人生各有各渡口，各有各舟，万般皆是命，半点不由人。看淡三千繁华，悟透人情冷暖，不言悲伤，只言温暖。 ...\n每一天都很累，所以叫人类 每天都很烦，所以叫凡人 生下来就要干活，所以就叫生活 上哪都要搬砖，所以就...\n已经很努力的在控制情绪了，但还是有点忍不住，给我按一个暂停键吧，我想缓缓….该用什么样的语言来形容我...',
#  '1111591283': '我和闺蜜聊某小寒就像搅屎棍，混淆视听，我俩都猜到了是刘&周[哪吒使坏]\n今天有人说我长得有点儿像鹤秋[哪吒嘟嘴]我看网上照片找了半天我俩的共同点，最后总结出两个字：好看\n渊不可能再有两年前的热度了，一方面舆情不可能让话题发酵，另一方面更新频率太慢，热度断断续续。还有，只...\n有的女艺人到现在总拿着台词营销，到现在还殊不知差在辨识度上吗，电影里操着一口方言的影帝影后照样受人喜...\n阔面脸真的不适合大银幕，就是上下一样宽的脸型特别不适合上镜，别再糟蹋观众啦 在电视剧里都近乎是容忍，...\n看到前几天开盒事件突然感叹坑爹的孩子不算少呀 听说开盒可以开全家 还好，我所有的社交账号都不是本人身...\n春游归来进屋就吃到了妈妈炖的雪燕桃胶和皂角米幸福感爆棚啦 妈妈为了找到奶茶的替代品，在做糖水的路上越...\n我有时候特别好奇某女艺人平时都怎么pua她老公的，是不是经常承诺这部剧会爆那部剧会爆，这部会上🐑视那...\n闺蜜说她妈妈今天大部分时间在花园里收拾花花草草，给植物们翻土，没感觉到地震 闺蜜担心家乡这两天会有余...\n带小姑去逛文房四宝展喽 她要开启买买买的模式啦，先去看糊州的毛笔，她闲下来时偶尔喜欢写小楷、画工笔画...',
#  '1112932770': '忽而立春，轮回新启。\n一个欢情而温暖的Home\n烟火起，照人间，慢享流年～\n然然在大学军训跳的《极乐净土》\n人生渐短，除了爱再不耕种其它……\n不知不觉陪伴她们 已经走了 这么远的路\n环境是有磁场的。 只有舒适了， 人才会快乐🎉\n在能走的时候，去过远方； 在不想走的时候，安于当下。\n我依旧是我。 是有序里偶尔的紊乱， 是常规里的浪漫和放纵。\n平静是另一种热情， 自己煨着自己， 自己让自己浓郁。 北京·通惠河畔',
#  '1117152144': '来上一刀，也就痛快了，爱谁谁\n【伟大2-0！郑钦文横扫克鲁格，超137万奖金，创造了历史，名利双收】中国球迷熬夜的比赛！北京时间凌...\n【俄乌两军杀红了眼，俄媒：拉平上将不幸阵亡】有关俄罗斯拉平上将在别尔格罗德遭乌军袭击阵亡的消息被传得...\n【2.5吨土豆变身成1吨干燥大米，“土豆米”到底啥味道？】土豆咱都不陌生，但土豆做成的“大米”，你尝...\n【美媒发现：恶果来了，12年新低】据多家美国媒体报道，美国一项常年关注消费者信心的指数显示，在通胀和...\n【马拉松亲密事件拍摄者最新发声：不是剧本，不认识这两位选手！又一批照片外泄，摄影机构回应】，无锡马拉...\n【反转！“野鸳鸯”双方身份均曝光，女方海量照片被扒，本人漂亮又优秀】真没想到，2025年无锡马拉松比...\n【国安部披露：外包保洁员投靠境外情报机关，泄露3项国家秘密】随着经济社会的快速发展，服务外包成为众多...\n【字节跳动美国电商梦受挫：高层不满，TikTok员工压力山大】字节跳动对TikTok电商在美国的发展...\n【缅甸5层酒店垮塌多人被埋，中国商人：不少同胞被困，多是做玉石生意】极目新闻记者张皓，缅甸发生7.9...',
#  '1133883182': ' 花开正好 暗香浮动\n中途休整下 迪庆·香格里拉虎跳峡景区\n等得好漫长啊一上午了还没保养好 饭点蹭个饭咯\n 新入手的越野跑鞋 两双配色我都好喜欢😍 纠结留下哪一双\n 这两天走路都是跛的 今天晚上去针灸后，重新裹上药膏 这下该老实了\n 咖啡展最后一天 拖着残腿过来小晃一下 凑个热闹～ 厦门·厦门国际会议展览中心\n 端午三天假期 完全在家躺平的三天， 不是睡就是在刷美剧or啃小零食、喝饮料🥤 除了早餐外，整整吃了...\n 崴脚的第六天 前两天去医院拍片，还好没有骨折骨裂 拿了两盒药膏回来贴，医生说先静养两周看恢复情况 ...\n 今天环东半马安全顺利完赛，这真是意外的惊喜 一路上我的坚持和努力，值了 冲线的那刻心情很复杂，有今...\n 植物园东门→海豚石→植物园南门→植物园赏花→五老峰→南普陀→鸿山寺→八市， 周末Citywalk～...',
#  '1133944377': ' 👆🏻🧵ⁿ，👇🏻🪡¹\n 线稿画好了，天亮上色 天津\n張信哲 关于你的事，我都能坚持很久\n海棠，你比任何化妆品都美！💄    天津\n張信哲 上班摸鱼，抓到同样摸鱼🐟的老板一只 天津\n張信哲 除夕快乐 有伙伴们知道哲哥用的是啥牌子的粉底么？\n 漫步在枫叶林间，仿佛置身于一幅美丽的画卷之中。   天津·宁园\n張信哲 我获得了 張信哲 的的“上上签蛇”头衔。以年为单位的热爱，永不停歇\n盲盒 第一次花钱抽盲盒，没有抽到草莓🍓熊🐻，史迪奇也还是可以的 天津·鲁能城购物中心\n張信哲 刚还在抱怨为啥不问候我，老板 你的饼🫓就来了 哥，2025新年快乐 [2025]',
#  '1136167331': '今日早餐：煎蛋肥牛河粉\n今日早餐：肥牛卷清汤、煎蛋炒米粉\n今日早餐：韭菜鸡蛋菜馍、煎蛋肥牛米线\n今日早餐：红枣芋头山药水、虾仁西葫芦烘蛋饼\n今日早餐：红枣枸杞银耳羹、香煎鸡小胸滑蛋三明治\n今日早餐：拌黄瓜、肉沫小白菜炒河粉 给我家小姑娘分享的，本来就是想她开心开心~结果，我好像吓到她了？\n今日早餐：奥利奥蓝莓酱双皮奶、酸菜肥牛卷荞麦面 这几天腿疼，小姑娘就紧张了，查了好些关于更年期症状的...\n今日早餐：发面单饼、酸辣粉 前两天打豆浆，花生黄豆豆浆真的很香。破壁机打的，剩下的豆渣就很细腻，昨晚...\n今日早餐：蜂蜜百香果汁、牛肉汤、泡菜炒饭 春天的风多，春天的花儿多 它们遇见的时候真好啊。 最后一张...',
#  '1139387047': '黔味美食集散地之一 贵阳·青云市集\n部好看的电影最top 贵阳·阿哈湖国家湿地公园\n春风十里不如你讨喜 日常 贵阳·阿哈湖国家湿地公园\n一直以为村超在乡里，殊不知是县城里 日常 黔东南·贵州村超足球场\n一元开启，人间可爱，值得期许，用实际行动护好2025！ 日常 贵阳·阿哈湖国家湿地公园\n2024读书盘点： 学习类选读了大部头书籍、《中华传统文化》、《新时代中国特色社会主义思想的世界观和...\n我没有朋友，我知晓外耗，因为我优秀，他们除了牙酸嘴利，嫉妒厌弃，一点办法都没有。 日常 贵阳·花果园...\n门 今早门禁罢工，在我的一番神功操作下直接哑火，不得已请求后台支援，在等待过程中，突然发现离了门禁，...\n苗王城，位于贵州松桃县，建于明洪武年，最早是苗族长官驻地，集政、经、文、军和建筑为一体的苗疆古城。 ...\n第一次踏上今年的长旅途行，春风都是带着温柔的野心——请把我的情绪剪辑成喜欢的色彩荡漾，撒满沿途。 镇...',
#  '1141951792': '阳台种菜愿望初步达成\n人回来了，心还在云南\n味道不错 就是排队太久了\n许久未用的杯子 还是很养眼哈\n这次在云南个人比较喜欢的菜品\n换了拉花缸，换了杯型，拉花又不会了\n天气冷了越发起不来，早餐桌也越来越简单了\n熬夜看剧的代价是上班迟到 必须靠咖啡续命\n冬天，有它独有的好 也到了拥有光影最多的季节✨\n听听歌，吹吹风，晒晒太阳 在细碎的美好里感受生活的温度',
#  '1143542943': '我知道你去了汪星，可这家里到处都是你的痕迹，让我忍不住想你。\n睡前回顾一天的收获，那些成长都是你的财富。带着这份满足入睡，晚安好梦。 每日一善\n💕《南部档案》紧张拍摄，丁禹兮挑战张海侠（张海虾）一角，悬疑剧情引人入胜，期待他的突破演绎！\n她只是去了一个没有病痛的地方，化作星辰在天上守护着你。她在你身边的日子，把满心的爱都给了你。那些一起...\n dyx 星河浩浩，你是宇宙的浩渺，梦想昭昭，你是希望的道。追寻未来的你，无畏前行的你，都令我心潮如...\n这个周日，在早餐的香气中，与自己来一场温柔对话。生活虽有起伏，但此刻的宁静与美味，提醒着我们美好常伴...\n✨✨ 每一个音符都像是一颗闪耀的星辰，在歌声的夜空中闪烁，用耀眼的光芒点亮了听众的心灵，触动着心底的...\n夜晚是生活给予的温柔喘息。今天的你或许疲惫，或许迷茫，但每一份坚持都在扎根，每一次努力都在靠近梦想。...\n世界就像一面镜子，你对它笑，它就对你笑；你对它善良，它也会回馈你温暖。每一个善意的举动，都是在为自己...',
#  '1144681142': '走在街头最安全的日子\n熟悉的配方0.5+1+2\n 看看我！在线蹲一个翻牌~\n为什么受伤的总是右手还是☝🏻\n打着灯笼也再找不到这么优秀的组织了\n既然如此，轻轻许个愿，年年有今日  摩登兄弟\n这么努力宣传的破万男主，手动点赞，正在海外热播呢\n都在合影留念，我也要，必须记住这一夜21：59登顶 摩登兄弟\n 。 。是大冒险还是什么打赌或者暗藏玄机，赢了奖励刘宇宁演唱会套票吗 摩登兄弟\n  摩登兄弟 咳咳咳，重点讲一讲哈，身体健康是第一位的，有且只有第一位哈 如果做不到虽然不能不要你了...',
#  '1145702053': '全马计划（325）丨\n全马计划（325）丨\n全马计划（325）丨\n 今天的腿有点沉，尤其是大腿😂\n 每周一次十公里跑进50分钟以内。\n不好好冲一把，怎么会知道自己的极限。\n今天跑坡，5.2公里的路程有三个坡：\n跑山便是中长跑运动中 1＞1的一种训练\n全马计划（325）丨 第188天 跑山\n很无语，现在🉐发两次打开内容，才算完成任务，太无语啦',
#  '1147177281': '已尽力～剩下的批量铲～\n感谢亲友送了板砖， 回头抱着啃\n有点心浮气躁， 所以画的不太好←临摹的，也没临好...\n虽然私下我烟酒（划掉）不，冰的冷的不忌口，但是 我昂提只来两天就结束我还是有点慌的...\n昨天和亲友约饭，送生日大礼包， 一堆小清新的吃穿用给亲友，用了可爱的行李包装着做了交易 （仿佛那什么...\n除夕惯例吃火锅～ 麻麻买了我心心念念的黄泥螺～ 饭后吃🍓喝小甜酒看春晚～←不是我 今年也要应看尽看跑...\n讲道理，明天抢票地狱，如果想要的场都没戏，那我只能再放手一抢5/7的卡... 你们是要上山攻打上剧场...\n今日city walk 先去龙华还愿请愿，给猫猫拍点神片，再跑龙华会吃点漂亮饭 之后跑黄浦文化中心去...\n从昨天下班，偏头痛发作了一天一夜还没好 全靠死撑，等它自己过去～今天提前30分钟睡了 【睡前再骂骂咧...\n讲道理，sd真的跑不动，虽然那天上海大剧院我从安检方位下楼抄近路跑了，但两百米后我还是虚脱...毕竟...',
#  '1147847417': '屏幕能隐藏那三个点吗\n多家媒体横评特斯拉FSD\n就照着理想L9来吧，照猫画虎\n迪士尼乐园换成哪吒乐园 才是真正成功的时候\n对于日结算合同利润率再次降低，底层人员工资被动降低\n我的智能用车日记 在满足从A点到B点的基础功能之外，汽车的智能化给用户带来前所未有的舒适便捷体验，已...\n开工不能没有理想的哪些设置？冬季打开预约充电，电池保温，按时出发，任务大师通勤模式上车自动调整座椅开...\n使用理想同学App，不仅有自研的MindGPT，现在和满血版DeepSeek强强联合，每次提问回答都...\n特斯拉的极简视觉方案席卷全球，理想用多传感器融合破解中国式复杂路况——匝道博弈、加塞预判、雨雾天透视...\n李想在2025年中关村论坛上宣布，理想汽车将全面开源其自研的汽车操作系统“理想星环OS”，这一举措成...',
#  '1149428177': '奥森追跑者 北京·北京奥森北园\n黑白胶片、自冲自扫。 北京·百子湾\n wan_wm的视频 再次露营北灵山\n奥森追焦跑者 跑步 北京·北京奥森北园\n wan_wm的视频 ～30日，暴雨中露营\n wan_wm的视频 ～～15日张家口桦皮岭雪地露营徒步穿越\n日有熹，月有光 富且昌,寿而康 新春嘉平,长乐未央！ 抚州·金溪\n2025年第一卷黑白胶卷 北京互免约拍 胶片复兴 黑白胶片摄影 北京\n 梦鱼_得鹿的视频 易中天为什么会被请去喝茶，看完这个视频你就了解了！！！\n做一名机械工程师很多年，今天下班徒步回家的路上突然想做一名系统开发部的总监的想法。 北京',
#  '1161073527': '💙深深你知道我喜欢你哪一点吗？每一点。\n💙只恨这时光太短，岁月太快，遇你的韶光转瞬即逝。\n💙我想把世界上最好的都给你，却发现世界上最好的就是你。\n💙💜时光静好，与君语；细水流年，与君同；繁华落尽，与君老。\n💙 不错过夏天，也不错过你。 十里春风十里路，一起成长不孤独\n💙周深，你是鱼跃莲池，惊起我心湖的一尾波浪，是江山万里，我只想与你相识。\n💙感谢周深 在音乐的路上从未停歇，奉献给大家一次次惊艳的演出和一首首过耳难忘的歌曲。\n💙喜欢周深 ，他唱歌好听风格百变，还有他的人品好，出道六年待人接物都谦逊有礼，不捧高踩低。人品好歌品...\n💙深深你在绽放，不是像摩斯密码一样断断续续，而是像直线一样无限延长，连续不断。你在发光，不是美国电影...\n💙词汇极度匮乏的我，说不出漂亮的辞藻，只有内心真诚的祝福大哥永远平安喜乐，永远幸福安康，永远平安顺遂...',
#  '1161468451': '先扔银之杰.....\n涨疯了，没涨的耐心等下去，比如我的\n还有2个点就开始赚钱了，加油，我的高新。。。。\n尾盘还是恐慌了一下下，不然明天都不知道怎么办了.....\n高新和银之杰之间选了高新，果然自己选的就是不行。连股票都这样….\n今天最好是再探个底，然后开始反弹。不过大A的尿性反弹最多也就三天，不能预期太好\ndeepseek建议我去广州黄大仙祠…..，为什么是黄大仙祠呢？这辈子都和姓黄的纠葛……，看来我的深...\n最好的婚姻状态：你挣钱我守家，我理解你的辛苦，你懂得我的不容易，你满眼是我，我满眼是孩子，你是我和孩...\n一个人的精力是有限的，要把有限的时间、精力留给那些更值得、更有意义的人身上，生活才能变得更好。不赌天...\n江东小霸王孙策说:内事不决问张昭，外事不决问周瑜。当我左右摇摆心不定；进退两难降不住时，我的张昭、周...',
#  '1167220041': '此次是去嘉兴，位于建国北路22号，由环城北路、建国北路、禾兴南路和同乐路围合而成。的基本结构是三河三...\n上午去市图本想着拿本书，结果看进去也拿多了。 恰好看到两本阶段的国统区和沦陷区的关于的，可以相互印证...\n今天把《王明中毒事件》给看完了，还算比较有趣的，这种事情也算是比较。 整本书讲述了的前因后果，分为三...\n这次是去郑打拼•贵州酸汤牛肉火锅的太原首店，位于2号楼3层，原来做冰煮羊的位置。 这两年开了不少，郑...\n此次是去芥小胖自助小火锅太原吾悦店，位于室内负一层靠近东北门。模式是回转小火锅，菜品基本都是从传送带...\n好像每年都会隆重庆祝生椰拿铁 ，如今也是生椰拿铁四周年了。仔细想想也对，之前黑料缠身都不看好，可横空...\n算是姗姗来迟，没看到有，只是单纯的奶茶杯和周边更新，依然是红蓝两种风格打底。没喝过的只有花田向晚，顺...\n今天动作有俯身绳索臂屈伸单臂20，有绳索锤式弯举50，上斜哑铃弯举单臂12.5，靠墙W杠弯举单侧12...\n此次是去桃南的茄子浇肉面，这家真是开了好多年。我也是好些年没吃，路过看到去吃了碗面。 店内基本没啥变...\n此次是去上海的一大会址纪念馆，位于黄陂南路374号。是在的老纪念馆旁边新建的，依然保持了的石库门统一...',
#  '1167855325': '今日早餐：泡芙（烤得有点焦 ）、红枣枸杞奶粉水铺蛋、煎蘑菇、豆干炒彩椒、橙子 大家周末愉快\n今日早餐：红薯奶酪、半根海参、鸡蛋、蔬菜沙拉、枫斗麦冬荸荠水，沙拉里加了酸黄瓜，口味一下子提高了一个...\n今日早餐：煎鲅鱼水饺、鸡蛋、青菜、蓝莓、姜黄牛奶，还有未出镜的综合坚果 昨天40分钟慢跑3.84公里...\n今日早餐：洋葱青椒胡萝卜豆干肉丝莜麦面、一个鸡蛋白加一丢丢黄、牛奶泡麦片、猕猴桃、芝麻核桃糕 鸡蛋是...\n今日早餐数数食材有几多 一碗饮品：红枣、红豆、熊猫豆、莲子、皂角米、桃胶、椰子粉；沙拉：小番茄、生菜...\n今日早餐：一碗多彩面：荞麦面白面+彩椒+洋葱+胡萝卜+黑木耳+芹菜叶+牛肉片；一碗蒸豆腐；一碟草莓 ...\n今日早餐：蒸馄饨、牛奶杂粮粥、煎虾仁、炒芹菜豆干百合香菇、黑蒜、人参果 昨天上午去上了舞蹈课，也算是...\n今日早餐：双色拌面+黄瓜和牛肉碎、凉拌贡菜、蓝莓草莓、姜黄奶 最近在追《三叉戟》，静怡在D融宝工作的...\n今日早餐：小香薯芋艿配奶酪、一碗汤：三文鱼+豆腐+鸡蛋+娃娃菜+生菜+裙带菜，小番茄、黑蒜和山楂，这...\n今日早餐：花卷馒头、水油焖杂菜（胡萝卜+彩椒+黑木耳+豆干+牛肉）、拇指黑提、小米山药苹果粥，甜味剂...',
#  '1171498500': '居然名列第一 意外收获\n 今天因为一个特殊状况需要在过关前停留，所以被暖心照顾在这个等候区坐下了…… 一个多小时的时间，看见...\n 59.8kg（from 62.5kg to 59.8kg） 惊闻一位朋友一年内减重35公斤，没有用...\n **kg（from 62.5kg to **kg） 这几天密集聚会外食 今天忘记称体重了，明天再上...\n 60.1kg（from 62.5kg to 60.1kg） 最近奔奔波波的，今天才停下来一下 下午...\n 2014年春节之后，这是第一次在家吃年夜饭 6个菜的年夜饭，祈愿诸事顺利！ 健健康康！平平安安！开...\n 60.0kg（from 62.5kg to 60.0kg） 大年初七 人日快乐 健健康康 开开心心...\n 60.1kg（from 62.5kg to 60.1kg） 今天弄到下午4点才吃，可惜昨晚追剧吃东...\n 59.4kg（from 62.5kg to 59.4kg） ·昨天 陪哥哥过生日，去楼下花店挑了新...\n ？kg（from 62.5kg to *kg） 终于定下来月底要去西藏了 现在只瑜伽不快步走了 最...',
#  '1171966494': '必品阁哈哈哈哈哈哈哈\n五岁就成为顶级赛车手的萌娃 \nkkt拉群之后居然被要求做这种事\n翻新卫生巾、一次性内裤爆雷，妈呀真的太难了\nfancon什么几把玩意 成团夜solo换成心肝？\n我公司团建的时候就唱的这首啊哈哈哈🤣很欢乐的一首歌，是首好歌\n延伸台？？接单接单！！代拍也行后面出了表格直接选座也行！！找我比别人都便宜\n啊啊啊好想买non no杂志和anan杂志都下架了 昊昊拍的老好看了 后悔 每次日本都拍的老帅\n这是在说董力？他做了什么呀为什么都在抨击他，好像说是节目剪辑？比利时的妻子看起来性格很好，妻子这边貌...\ncj装都不装了，韩国人chb莫名其妙偷饺子塑开始，就初见端倪。说什么请推荐饺子塑艺人，下面全都是说z...',
#  '1173559413': '表演一个洗车给你们看看\n今年让我最幸运的伊利福桶\n每天玩一玩，总有一天轮到我   \n 第四弹库可冰升级上新！ 快和我一起喝一杯生椰拿铁库可冰，感受椰香与咖香的平衡 ！还有张杰北京演唱会...\n加完班的夜晚，疲惫与孤独如影随形。但一打开家门，小狗就摇着尾巴扑来，往我怀里钻。周末赖床，它会跳上床...\n  忙碌一天回到家，瘫倒在沙发……直到狗狗闯进我的世界，它毫无保留的爱瞬间将我治愈。清晨它热情的迎接...\n我的狗狗，它就像一道光照进我黯淡的生活。清晨，它会用湿漉漉的鼻子拱醒我，开启活力满满的一天；夜晚，它...\n刚搬到陌生城市时，工作高压，社交空白，我就像一座孤岛，被孤独和焦虑包围。在一次周末闲逛时，我被一家手...\n入手ID与众已有小半年，它就像生活里的可靠伙伴 。车机智能，导航精准，每次输入目的地，都能迅速规划路...'}

# %% [markdown]
# #### 设计 Prompt
# - 这是最关键的部分，大模型的数据清洗效果很大程度上取决于 Prompt
# - 大致思路是将 `sampled_weibo_dict` 输入给大模型，让大模型返回需要被清洗的用户 ID 组成的列表
# - 一些实践：
#   1. 为了评估大模型的清洗效果，我首先自己浏览了样本用户的微博内容，手动标注了我认为需要被清洗的用户的 ID，得到 `my_selected_list` 列表
#   2. 对于 Prompt 的设计，一开始我采用了简短的描述，要求大模型筛选出没有表达出个人生活情感的用户。效果：容易遗漏，并且输出不稳定（时多时少）
#   3. 接着，我将 `sampled_weibo_dict` 和 `my_selected_list` 输入给 DeepSeek-R1 模型，要求它分析我手动标注的这些用户微博内容，总结它们的共性特点，改善 API 的 Prompt，最终使用的 Prompt 如下：
#    > 你是一名专业的社交媒体信息分析师，请根据用户发布的微博内容判断是否为生活分享账号，需满足以下至少2项特征：
#    > 1. 包含具体生活场景/人物互动/个人经历
#    > 2. 使用第一人称主观表达（如"我"的感受/经历）
#    > 3. 内容呈现非结构化自然叙述（非列表/教程/资讯格式）
#    > 4. 涉及日常活动（饮食/出行/家庭/宠物等）
#    >
#    > 需排除以下特征账号：
#    > - 垂直领域专业内容（医疗/法律/金融等）
#    > - 商品交易/广告推广信息
#    > - 抽象理论/鸡汤语录/政策转载
#    >
#    > 接下来我将给出一个JSON文件，其中键是用户ID，值是经过采样后的微博内容。
#    >
#    > 请直接为我返回一个列表，其中的元素是需要排除的用户的ID，除此之外不需要给出其他信息。
#    >
#    > 返回示例：[1234567890, 2345678901, ...]
#
# - 采用改善后的 Prompt，大模型的输出质量有所提高，不过仍会存在输出不稳定的情况
# - 于是，提出一个想法：让大模型多次分析，综合结果来决定清洗方式。具体做法：
#   - 让大模型连续分析3次，得到3个清洗用户的列表
#   - 对列表中的 ID 进行计数：对于出现3次或2次的用户，可以直接从数据集中排除；对于只出现了1次的用户，则人工检查和决定清洗或保留

# %%
from openai import OpenAI

with open("../weibo_config.json", 'r', encoding='utf-8') as f:
    config = json.load(f)



prompt = """
你是一名专业的社交媒体信息分析师，请根据用户发布的微博内容判断是否为生活分享账号，需满足以下至少2项特征：
1. 包含具体生活场景/人物互动/个人经历
2. 使用第一人称主观表达（如"我"的感受/经历）
3. 内容呈现非结构化自然叙述（非列表/教程/资讯格式）
4. 涉及日常活动（饮食/出行/家庭/宠物等）

需排除以下特征账号：
• 垂直领域专业内容（医疗/法律/金融等）
• 商品交易/广告推广信息
• 抽象理论/鸡汤语录/政策转载
接下来我将给出一个JSON文件，其中键是用户ID，值是经过采样后的微博内容。
请直接为我返回一个列表，其中的元素是需要排除的用户的ID，除此之外不需要给出其他信息。
返回示例：[1234567890, 2345678901, ...]
"""

def validity_analysis(api_config: dict, prompt: str, sampled_weibo):
    base_url = api_config["base_url"]
    model = api_config["model"]
    api_key = api_config["api_key"]
    if isinstance(api_key, list):
        api_key = api_key[0]
    if not isinstance(sampled_weibo, str):
        if isinstance(sampled_weibo, dict):
            sampled_weibo = json.dumps(sampled_weibo, ensure_ascii=False)
        else:
            sampled_weibo = str(sampled_weibo)
        
    client = OpenAI(api_key=api_key, base_url=base_url)


    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": prompt},
            {"role": "user", "content": sampled_weibo},
        ],
        temperature=1.0, 
        stream=False
    )

    return response.choices[0].message.content


# 读取配置文件
with open(r"../weibo_config.json", 'r', encoding='utf-8') as f:
    config = json.load(f)

llm_config = config["LLM_API"]["DeepSeek-v3"]

# %%
import time
from collections import Counter

outputs = []
# 连续3次分析
for i in range(3):
    start = time.time()
    output = validity_analysis(llm_config, prompt, sampled_weibo_dict)
    end = time.time()
    print(f"第 {i + 1} 次分析，用时 {end - start:.2f} 秒")
    outputs.append(output)

selected_user_list = []
for output in outputs:
    user_list = output[1:-1].split(', ')
    user_list = [user.strip('"').strip("'") for user in user_list]
    selected_user_list.extend(user_list)

user_counter = Counter(selected_user_list)
# Out:
# 第 1 次分析，用时 12.40 秒
# 第 2 次分析，用时 13.86 秒
# 第 3 次分析，用时 20.74 秒

# %% [markdown]
# #### 大模型分析后的处理
# - 上面向大模型输入的用户数约为100
# - 经过多次重复测试，大模型分析的用时基本在10~20秒，取平均值15秒，则大模型分析一个用户是否应该被清洗的平均用时约为
# $$\frac{15\times 3}{100}=0.45\text{s}\approx 0.5\text{s}$$
# - 因此，如果分析完收集的约15000个用户的有效性，用时约为
# $$15000\times 0.5 = 75000\text{s}\approx21\text{h}$$

# %%
cleaned_user_list = [user for user, freq in user_counter.items() if freq >= 2]
manual_examine_user_list = [user for user, freq in user_counter.items() if freq == 1]

cleaned_count = len(cleaned_user_list)
manual_count = len(manual_examine_user_list)
total_count = len(user_dict)


print(f"直接删除用户数：{cleaned_count}；人工筛选用户数：{manual_count}")
print(f"直接删除比例：{cleaned_count/total_count:.2f}；人工筛选比例：{manual_count/total_count:.2f}")
# Out:
# 直接删除用户数：33；人工筛选用户数：7
# 直接删除比例：0.34；人工筛选比例：0.07

# %% [markdown]
# 后续批量处理时，可以将需要人工检查的那部分用户 ID 专门存于一个文本文档中。
#
# 同时，后续有可能需要再次检查被大模型清洗掉的那部分用户（数据量不足时），因此，可以将出现次数等于2的用户单独记录在一个文本文件中

# %%
manual_examine_file = "manual_examine.txt"
cleaned_user_file = "cleaned_users_2.txt"  # 2 代表出现次数等于2

with open(manual_examine_file, 'a', encoding='utf-8') as f:
    f.writelines('\n'.join(manual_examine_user_list))

with open(cleaned_user_file, 'a', encoding='utf-8') as f:
    f.writelines('\n'.join(user for user, freq in user_counter.items() if freq == 2))

# %% [markdown]
# - 人工筛选的比例基本在5%~10%左右，取平均值7.5%。故对于15000个总用户来说，需要手动筛选的用户数约为
# $$15000\times 7.5\% = 1125$$
# - 下面手动检查这7人的微博，方法是从他们未经采样处理的微博中随机收集10条微博，检查这些微博是否表露出情感倾向

# %%
for user_id in manual_examine_user_list:
    weibo_list = user_dict[user_id]["weibo"]
    sampled_weibo_list = random.sample(weibo_list, 10)
    print(f"{user_id}:")
    for i, weibo in enumerate(sampled_weibo_list):
        text = weibo["text"]
        print(f'({i + 1}) {text[:min(50, len(text))]}', end='')
        print('...' if len(text) > 50 else '')
    print('-'*50)
# Out:
# 1136167331:
# (1) #生活手记#今日早餐：百香果茶、煎蛋香肠、土豆丝煎饼
# (2) #生活手记#今日早餐：百合山药水、煎蛋肉沫炒荞 新入手一大箱子荞麦方便面，嗯，想着来两块儿面饼吧，毕...
# (3) #生活手记#今日早餐：西红柿菠菜豆腐汤
# (4) #生活手记#今日早餐：红枣山药水、韭菜盒子
# (5) #生活手记#今天仍然一餐，昨天的帕尼尼一个，韭菜肉馅儿馄饨一碗。韭菜再不吃就要坏掉了，馄饨皮也是 。...
# (6) #生活手记#今日早餐：发面单饼、酸辣粉 前两天打豆浆，花生黄豆豆浆真的很香。破壁机打的，剩下的豆渣就...
# (7) #生活手记#今日早餐：牛奶、鸡蛋酱吐司、烤肠
# (8) #生活手记#今日早餐：杂粮粥、芹菜炒肉片 一天一锅粥，也不是不行哈 ~但我刚才去泡了牛奶燕麦，所以说...
# (9) #生活手记#今日早午餐：橙皮百香果汁茶、鲜肉小馄饨、韭菜盒子
# (10) #生活手记#今日早餐：野菜包子、胡辣汤
# --------------------------------------------------
# 1141951792:
# (1) #生活手记#换了拉花缸，换了杯型，拉花又不会了
# (2) #生活手记#许久未用的杯子 还是很养眼哈
# (3) #生活手记#追日🌄
# (4) #生活手记#早安☕️
# (5) #生活手记#抹茶🍵拿铁 卖相不行 味道不错
# (6) #生活手记#元宵节快乐
# (7) #生活手记#早安
# (8) #生活手记#coffee everyday ☕️
# (9) #生活手记#浪里个浪 上海·古猗庄园
# (10) #生活手记#阳台种菜愿望初步达成
# --------------------------------------------------
# 1144681142:
# (1) #猫猫的奇幻漂流奥斯卡最佳动画长片#恭喜猫猫
# (2) #刘宇宁海飞丝活力代言人# #刘宇宁开始推理吧# 摩登兄弟 知所从来，思所将往方明所去，我还没编好说...
# (3) #刘宇宁燕子京2024微博热议男角色#所以说嘛刘宇宁的剧，必看 摩登兄弟
# (4) 春困开始了
# (5) 熟悉的配方0.5+1+2
# (6) #刘宇宁海飞丝活力代言人# #刘宇宁开始推理吧# 摩登兄弟 好好好，就欢喜你这般自有规划的独立意志，...
# (7) #刘宇宁维护工作室#这才是成熟男人该做的事
# (8) #刘宇宁开始推理吧# #刘宇宁海飞丝活力代言人# 摩登兄弟 哎嘿，又到周末了，终于迎来了2025年的...
# (9) #刘宇宁开始推理吧# #刘宇宁海飞丝活力代言人# 摩登兄弟 咳咳咳，重点讲一讲哈，身体健康是第一位的...
# (10) #刘宇宁 珠帘玉幕咋了#这么优秀的正能量(真和你聊)艺人怎么可能不爱，期待多平台破万男主的诞生#刘宇...
# --------------------------------------------------
# 1147177281:
# (1) 虽然昨天被同担夸我出的物料好看有心思， 其实是我心虚得知道，萌新小白找不来品控好工艺好的定制厂家，最...
# (2) 画完，瘫一会，晚上继续起稿～ （看了下新工位的位置，可能大概以后摸鱼机会大大提升 ）
# (3) 一种新型偷摸企图提高物料高级感的偷懒方法...↓二创加工... a 差不多想做成这样
# (4) 本来下单做方卡和吧唧，想试试白瓷和烫金的工艺，后来想想自己画的又不好，不配做烫金... _(:з」∠...
# (5) 3/22又来看道林， 人，这辈子不可以不看道林 虽然两天的场次前面观众脑袋太高导致我精彩地方都被挡住...
# (6) 关于下午又在捣鼓什么劲儿了～ 把我光秃的手冲壶美化了一下... 顺便冲今朝八弄凑个热闹， 拿到财神爷...
# (7) 今日闲逛～ 早上先去看封神， 请问婵玉姐姐缺姐妹吗 中午跑萨莉亚随意一顿～ T9家饮料好喝 逐与太太...
# (8) 虽然私下我烟酒（划掉）不，冰的冷的不忌口，但是 我昂提只来两天就结束我还是有点慌的...
# (9) 定制物料也真的是需要研究的活儿， 从价格，到工艺，到成品。 讲道理，这色差我眼前一黑又一黑
# (10) 昨晚的进度
# --------------------------------------------------
# 1167855325:
# (1) #每日一餐分享#今日早餐：一份甜品，加了奶粉和蛋白粉有点甜；一份小炒，绿色的是芹菜边角料，还有牛肉和...
# (2) #每日一餐分享#今日早餐：生煎包、红薯、奶酪、水油焖花菜+蘑菇+胡萝卜+油豆腐+黑木耳+肉丸 坚果、...
# (3) #每日一餐分享#今日早餐：红薯芋奶、煎三文鱼、凉拌菠菜胡萝卜、小番茄、坚果、柿饼，一杯清水 感觉今日...
# (4) #每日一餐分享#今日早餐：南瓜、鸡肉条、炒芹菜胡萝卜香菇豆干、红豆莲子桃胶牛奶、猕猴桃、坚果，炒菜太...
# (5) #每日一餐分享#今日早餐：洋葱青椒胡萝卜豆干肉丝莜麦面、一个鸡蛋白加一丢丢黄、牛奶泡麦片、猕猴桃、芝...
# (6) #每日一餐分享#今日早餐：炒莜面胡萝卜莴笋肉丝、坚果、海参拌香菜、红枣杂豆糊糊加亚麻籽和黑芝麻种子碎...
# (7) #每日一餐分享#今日早餐：蔬菜沙拉、三文鱼、坚果、小香薯、芋艿、牛奶、草莓，干干净净，清清爽爽 昨天...
# (8) #每日一餐分享#今日早餐：蒸馄饨、牛奶杂粮粥、煎虾仁、炒芹菜豆干百合香菇、黑蒜、人参果 昨天上午去上...
# (9) #每日一餐分享#今日早餐图片打卡
# (10) #每日一餐分享#今日早餐：荠菜肉馅大馄饨、大拌菜、鸡蛋 馄饨皮买的是黑皮，也算是粗细搭配啦 不过，感...
# --------------------------------------------------
# 1171498500:
# (1) #两个喵星人# 今晚要去接安安猫女儿回家，出门前糯糯宝贝慌张地咿呀乱叫，应该是前几天我们外出了三天她...
# (2) #减肥# 59.5kg（from 62.5kg to 59.5kg） 昨天的哑铃计划没有执行，只是玩...
# (3) #广州的花市# 每年春节前的行花街是很有年味的事情 降温之后在冷冷的空气中行花街更有年味#广州迎春花...
# (4) #猫年# 说古代壁画中的十二生肖有猫没蛇 属蛇的猫奴应该很开心了 我作为非属蛇的猫奴也很开心有一个猫...
# (5) #减肥# 59.4kg（from 62.5kg to 59.4kg） ·昨天 陪哥哥过生日，去楼下花...
# (6) #减肥# 60.0kg（from 62.5kg to 60.0kg） 大年初七 人日快乐 健健康康 ...
# (7) #减肥# 59.2kg（from 62.5kg to 59.2kg） 昨天只吃了yig正餐，晚上超慢...
# (8) #年夜饭# 2014年春节之后，这是第一次在家吃年夜饭 6个菜的年夜饭，祈愿诸事顺利！ 健健康康！平...
# (9) #初六立春# 2025.02.03 · 初六 ·立春 喜欢0203 喜欢初六 喜欢立春 看着这些感觉...
# (10) #清明节# 这个清明不太一样，觉得有点魔幻…… 11月到3/25，也不是没有心理准备，但最后不到24...
# --------------------------------------------------
# 1173559413:
# (1) 表演一个洗车给你们看看
# (2) 刚搬到陌生城市时，工作高压，社交空白，我就像一座孤岛，被孤独和焦虑包围。在一次周末闲逛时，我被一家手...
# (3) 入手ID与众已有小半年，它就像生活里的可靠伙伴 。车机智能，导航精准，每次输入目的地，都能迅速规划路...
# (4) 加完班的夜晚，疲惫与孤独如影随形。但一打开家门，小狗就摇着尾巴扑来，往我怀里钻。周末赖床，它会跳上床...
# (5) 每天玩一玩，总有一天轮到我#喝伊利赢金元宝#@活力伊利 @一只小抱扑 @小迪369_387 @北方开...
# (6) 就是这么毫#春节寻宝记##喝伊利有机会赢金元宝##哪里过春节拿礼有伊利# @活力伊利
# (7) 我的狗狗，它就像一道光照进我黯淡的生活。清晨，它会用湿漉漉的鼻子拱醒我，开启活力满满的一天；夜晚，它...
# (8) #她的情绪疗愈日记#@活力伊利 @CHARMNOTES颂境 忙碌一天回到家，瘫倒在沙发……直到狗狗闯...
# (9) 今年让我最幸运的伊利福桶#哪里过春节拿礼有伊利##喝伊利赢金元宝#
# (10) #库迪百万大咖免费测评# 第四弹库可冰升级上新！#做一个冷库打工人# 快和我一起喝一杯生椰拿铁库可冰...
# --------------------------------------------------

# %% [markdown]
# 从这7人中，筛选出以下3人保留：['1147177281', '1171498500', '1173559413']

# %%
valid_user_list = ['1147177281', '1171498500', '1173559413']

cleaned_user_list.extend([user for user in manual_examine_user_list 
                          if user not in valid_user_list])

for user_id in cleaned_user_list:
    user_dict.pop(user_id)

# %% [markdown]
# 最后，将清洗后的数据集存入数据库的 `user_cleaned` 表和 `weibo_cleaned` 表中，进行后续的情感分析。

# %%
import pymysql

# 读取配置文件
with open('weibo_config.json', 'r') as f:
    config = json.load(f)

# %%
user_list = []
weibo_list = []

for user_id, user_info in user_dict.items():
    user_data = {
        "id": user_id, 
        "screen_name": user_info["screen_name"], 
        "sex": user_info["sex"], 
        "statuses_count": user_info["statuses_count"], 
        "IP": user_info["IP"]
    }
    user_list.append(user_data)

    for weibo in user_info["weibo"]:
        created_at = weibo["created_at"].replace('T', ' ')

        weibo_data = {
            "weibo_id": weibo["weibo_id"], 
            "user_id": user_id, 
            "text": weibo["text"], 
            "created_at": created_at, 
            "attitudes_count": weibo["attitudes_count"], 
            "comments_count": weibo["comments_count"], 
            "reposts_count": weibo["reposts_count"]
        }
        weibo_list.append(weibo_data)

with pymysql.connect(**config['database']) as conn:
    try:
        with conn.cursor() as cursor:
            user_sql = """
                INSERT INTO user_cleaned
                (uid, screen_name, sex, statuses_count, IP)
                VALUES
                (%(id)s, %(screen_name)s, %(sex)s, %(statuses_count)s, %(IP)s)
            """
            cursor.executemany(user_sql, user_list)

            weibo_sql = """
                INSERT INTO weibo_cleaned
                (wid, user_id, text, created_at, 
                attitudes_count, comments_count, reposts_count)
                VALUES
                (%(weibo_id)s, %(user_id)s, %(text)s, %(created_at)s, 
                %(attitudes_count)s, %(comments_count)s, %(reposts_count)s)
            """
            cursor.executemany(weibo_sql, weibo_list)

        conn.commit()
        print(f"数据插入成功，共插入 {len(user_list)} 个用户，{len(weibo_list)} 条微博")
    
    except Exception as e:
        conn.rollback()
        print(f"数据插入失败，已回滚：{e}")
        raise
# Out:
# 数据插入成功，共插入 59 个用户，2468 条微博

# %% [markdown]
# - 经过清洗阶段，从100个用户得到59个有效用户，有效率约为60%
# - 因此，对于15000个总用户，最终得到的有效用户数约为
# $$15000 \times 60\% = 9000$$

# %% [markdown]
# 将出现2次的用户及其微博组成字典，存于JSON文件，便于检查

# %%
import json

with open("cleaned_users_2.txt", 'r', encoding='utf-8') as f:
    cleaned_users_2 = f.readlines()
    cleaned_users_2 = [user.strip() for user in cleaned_users_2]

cleaned_users_2_weibo = {}
for user_id in cleaned_users_2:
    user_info = user_dict[user_id]
    weibo_text_list = [weibo["text"] for weibo in user_info["weibo"]]
    cleaned_users_2_weibo.update({user_id: weibo_text_list})



with open("cleaned_user_2_weibo.json", 'w', encoding='utf-8') as f:
    json.dump(cleaned_users_2_weibo, f, ensure_ascii=False, indent=4)

# %%
import json

with open("test100cleaned.json", 'r', encoding='utf-8') as f:
    user_dict:dict = json.load(f)

new_dict = {}

for user_id, user_info in user_dict.items():
    user = user_info
    user["weibo"] = [weibo["text"] for weibo in user_info["weibo"]]
    new_dict[user_id] = user

with open("test100_Cleaned.json", 'w', encoding='utf-8') as f:
    json.dump(new_dict, f, ensure_ascii=False, indent=4)
